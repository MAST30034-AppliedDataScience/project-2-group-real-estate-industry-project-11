# %%
import pandas as pd
import requests

# %% [markdown]
# ## NOTES

# %% [markdown]
# - I have only gotten the format for the urls, haven't created the entire file system, intend to do probably on saturday
# - School data haven't gotten because I'm not sure it'd be the best suited for our needs
#   - Only lists government schools
#   - Not sure if we want the actual location, but I suppose we could try use a google maps API call if needed to
#   - Not sure if we want some metric for the quality of the school, like median atar or something stupid

# %% [markdown]
# ## Historic Listings

# %% [markdown]
# - **NOTE:** there are many sheets involved with this that go from
#   - 1-3 bedroom flat
#   - 2-4 bedroom house
#   - Have only sampled one sheet

# %%
LISTINGS_URL = "https://www.dffh.vic.gov.au/moving-annual-rents-suburb-march-quarter-2023-excel"
data = requests.get(LISTINGS_URL).content

# %%
rows_skip = list(range(1))

df = pd.read_excel(data,
                   sheet_name="1 bedroom flat",
                   skiprows=rows_skip,
                   index_col=[0, 1], 
                   header=[0, 1])

df.head()
# Out:
# Moving annual rent by suburb                          Mar 2000         \
# 1 bedroom flat                                           Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      352    165
#                 Armadale                                   210    150
#                 Carlton North                               87    150
#                 Carlton-Parkville                          303    165
#                 CBD-St Kilda Rd                            755    250
#
# Moving annual rent by suburb                          Jun 2000         \
# 1 bedroom flat                                           Count Median
# Inner Melbourne Albert Park-Middle Park-West St Kilda      347    165
#                 Armadale                                   212    150
#                 Carlton North                               78    155
#                 Carlton-Parkville                          300    170
# ...

# %% [markdown]
# ## Interest Rates

# %%
LENDING_URL = "https://www.rba.gov.au/statistics/tables/xls/f06hist.xlsx"
DEPOSIT_RATES = "https://www.rba.gov.au/statistics/tables/xls/f04hist.xlsx"
PAID_DEPOSIT_RATES = "https://www.rba.gov.au/statistics/tables/xls/f04-1-hist.xlsx"

# %%
data = requests.get(LENDING_URL).content

rows_skip = list(range(11))
rows_skip.pop(1)

df = pd.read_excel(data, 
                   sheet_name="Data",
                   skiprows=rows_skip,
                   index_col=0, 
                   header=0)

df.sample(5)
# Out:
#             Lending rates; Housing credit; Outstanding; Owner-occupied; All loans; Large institutions  \
# Title
# 2020-11-30                                               3.08
# 2019-07-31                                               3.83
# 2024-02-29                                               5.89
# 2023-11-30                                               5.80
# 2024-06-30                                               6.02
#
#             Lending rates; Housing credit; Outstanding; Owner-occupied; All loans; All institutions  \
# Title
# 2020-11-30                                               3.09
# 2019-07-31                                               3.84
# 2024-02-29                                               5.91
# 2023-11-30                                               5.80
# 2024-06-30                                               6.03
#
#             Lending rates; Housing credit; Outstanding; Owner-occupied; Variable-rate; Large institutions  \
# Title
# ...

# %%
data = requests.get(DEPOSIT_RATES).content

rows_skip = list(range(11))
rows_skip.pop(1)

df = pd.read_excel(data, 
                   sheet_name="Data",
                   skiprows=rows_skip,
                   index_col=0, 
                   header=0)

df.head(5)
# Out:
#             Retail deposit and investment rates; Transaction accounts; Banks; $5000  \
# Title
# 1981-12-31                                                NaN
# 1982-01-31                                                NaN
# 1982-02-28                                                NaN
# 1982-03-31                                                NaN
# 1982-04-30                                                NaN
#
#             Retail deposit and investment rates; Transaction accounts; Building societies; $5000  \
# Title
# 1981-12-31                                                NaN
# 1982-01-31                                                NaN
# 1982-02-28                                                NaN
# 1982-03-31                                                NaN
# 1982-04-30                                                NaN
#
#             Retail deposit and investment rates; Transaction accounts; Credit unions; $5000  \
# Title
# ...

# %%
data = requests.get(PAID_DEPOSIT_RATES).content

rows_skip = list(range(11))
rows_skip.pop(1)

df = pd.read_excel(data, 
                   sheet_name="Data",
                   skiprows=rows_skip,
                   index_col=0, 
                   header=0)

df.sample(5)

# %% [markdown]
# ## GDP

# %%
import csv

"""Assumes a bs4 object has been passed in"""
def tag_to_csv(table_tag, dst_path):
    with open(dst_path, mode='w', newline='', encoding='utf-8') as csv_file:
        writer = csv.writer(csv_file)

        # Iterate through table rows <tr>
        for row in table_tag.find_all('tr'):
            # Get all <td> or <th> in the row
            columns = row.find_all(['td', 'th'])

            # Extract text from each column and write the row to the CSV file
            writer.writerow([col.text.strip() for col in columns])

# %%
from bs4 import BeautifulSoup

def write_table(string, url, dst_path="experiment.csv"):
    content = requests.get(url).content
    soup = BeautifulSoup(content, 'lxml')
    
    caption_tag = soup.find('caption', string=string)

    table_tag = caption_tag.find_parent()

    tag_to_csv(table_tag, dst_path)

# %%
# no #1: Gross domestic product, chain volume measures, seasonally adjusted
#
GDP_URL = "https://www.abs.gov.au/statistics/economy/national-accounts/australian-national-accounts-national-income-expenditure-and-product/latest-release"
gdp_string = "Gross domestic product, chain volume measures, seasonally adjusted"

# %%
write_table(gdp_string, GDP_URL)

pd.read_csv("experiment.csv", index_col=0).head(5)
# Out:
#         Levels (RHS) ($b)  Quarterly growth (%)
# Jun-16              516.5                   0.6
# Sep-16              516.6                   0.0
# Dec-16              522.6                   1.2
# Mar-17              524.3                   0.3
# Jun-17              527.6                   0.6

# %% [markdown]
# ## Immigration

# %%
IMMIGRATION_URL = "https://www.abs.gov.au/statistics/people/population/overseas-migration/2022-23-financial-year/34070DO001_202223.xlsx"

data = requests.get(IMMIGRATION_URL).content

# %%
rows_skip = list(range(12))

df = pd.read_excel(data, 
                   sheet_name="Table 1.3",
                   skiprows=rows_skip,
                   index_col=0, 
                   header=0, 
                   nrows=250)

# %%
df.head(5)
# Out:
#              Country of birth(c)  2004-05  2005-06  2006-07  2007-08  2008-09  \
# SACC code(c)
# 1101                   Australia    -4140    -3210    -3550    -4010     -150
# 1102           Norfolk Island(e)        0        0        0        0        0
# 1199               Aust E T, nec        0        0        0        0        0
# 1201                 New Zealand     3040     3240     3570     4090     3810
# 1301               New Caledonia        0       10        0       10       10
#
#               2009-10  2010-11  2011-12  2012-13  2013-14  2014-15  2015-16  \
# SACC code(c)
# 1101             -690    -2020    -1480    -2310    -4380    -5710    -5030
# 1102                0        0        0        0        0        0        0
# 1199                0        0        0        0        0        0        0
# 1201             3290     6060     7090     5640     2740     1630     2050
# 1301               20      -10       10        0        0       10        0
#
# ...

# %% [markdown]
# ## Age Demos

# %%
AGE_DEMO_URL = "https://www.abs.gov.au/statistics/people/population/regional-population-age-and-sex/2023/32350DS0005_2001-23.xlsx"

data = requests.get(AGE_DEMO_URL).content

# %%
rows_skip = list(range(6))

df = pd.read_excel(data, 
                   sheet_name="Table 3",
                   skiprows=rows_skip,
                   index_col=0, 
                   header=0) \
.iloc[:-1]

# %%
df.head(5)
# Out:
#             Australian Bureau of Statistics                                                                          Earners (persons)  \
# Personal Income in Australia: Table 1. Total income, earners and summary statistics by geography, 2016-17 to 2020-21           2016-17
# Australia       SA2 NAME                                                                                                    13,675,002
# New South Wales SA2 NAME                                                                                                     4,344,142
# 101021007       Braidwood                                                                                                        2,261
# 101021008       Karabar                                                                                                          4,989
# 101021009       Queanbeyan                                                                                                       6,482
#
# ...

# %% [markdown]
# ## Population Projections

# %%
POPULATION_PROJ_URL = "https://www.abs.gov.au/statistics/people/population/population-projections-australia/latest-release"
string = "Projected population, Victoria"

write_table(string, POPULATION_PROJ_URL)
pd.read_csv("experiment.csv", index_col=0).head(5)
# Out:
#      High series Medium series Low series
# 2022   6,630,258     6,630,258  6,630,258
# 2023   6,793,450     6,775,597  6,758,046
# 2024   6,941,905     6,898,479  6,862,260
# 2025   7,094,861     7,023,308  6,965,405
# 2026   7,252,691     7,152,161  7,066,644

# %%
string = "Projected natural increase, Victoria"

write_table(string, POPULATION_PROJ_URL)
pd.read_csv("experiment.csv", index_col=0).head(5)
# Out:
#      High series Medium series Low series
# 2022      31,624        31,624     31,624
# 2023      30,692        29,839     29,038
# 2024      32,580        30,007     27,589
# 2025      34,363        29,930     25,835
# 2026      36,616        30,239     24,407

# %%
string = "Population proportion(a), Victoria"

write_table(string, POPULATION_PROJ_URL)
pd.read_csv("experiment.csv", index_col=0).head(5)
# Out:
#      ERP - 2022 (%) (%)  High series - 2071 (%) (%)  \
# Age
# 0                  1.17                        1.01
# 1                  1.16                        1.01
# 2                  1.14                        1.01
# 3                  1.17                        1.01
# 4                  1.18                        1.02
#
#      Medium series - 2071 (%) (%)  Low series - 2071 (%) (%)
# Age
# 0                            0.92                       0.78
# 1                            0.92                       0.79
# 2                            0.92                       0.79
# 3                            0.92                       0.80
# 4                            0.93                       0.80

# %% [markdown]
# ## Socio Economic

# %%
SOCIO_URL_1 = "https://www.abs.gov.au/statistics/labour/earnings-and-working-conditions/personal-income-australia/2020-21-financial-year/Table%201%20-%20Total%20income%2C%20earners%20and%20summary%20statistics%20by%20geography%2C%202016-17%20to%202020-21.xlsx"

data = requests.get(SOCIO_URL_1).content

# %%
# getting the lowest level granuality

rows_skip = list(range(5))

df = pd.read_excel(data, 
                   sheet_name="Table 1.4",
                   skiprows=rows_skip,
                   index_col=[0, 1], 
                   header=[0, 1]) \
.iloc[:-5]

# %%
df.head(5)
# Out:
#             Australian Bureau of Statistics                                                                          Earners (persons)  \
# Personal Income in Australia: Table 1. Total income, earners and summary statistics by geography, 2016-17 to 2020-21           2016-17
# Australia       SA2 NAME                                                                                                    13,675,002
# New South Wales SA2 NAME                                                                                                     4,344,142
# 101021007       Braidwood                                                                                                        2,261
# 101021008       Karabar                                                                                                          4,989
# 101021009       Queanbeyan                                                                                                       6,482
#
# ...

# %%
SOCIO_URL_2 = "https://www.abs.gov.au/statistics/labour/earnings-and-working-conditions/personal-income-australia/2020-21-financial-year/Table%202%20-%20Total%20income%20distribution%20by%20geography%2C%202020-21.xlsx"

data = requests.get(SOCIO_URL_2).content

# %%
# getting the lowest level granuality

rows_skip = list(range(4)) + []

df = pd.read_excel(data, 
                   sheet_name="Table 2.4",
                   skiprows=rows_skip,
                   index_col=[0, 1], 
                   header=[0, 1, 2]) \
.iloc[:-5]

# %%
df.head(5)
# Out:
#             Australian Bureau of Statistics                                            Unnamed: 2_level_0  \
# Personal Income in Australia: Table 2. Total income distribution by geography, 2020-21            Earners
# Released at 11.30am (Canberra time) 6 December 2023                                             (persons)
# Australia       SA2 NAME                                                                       14,760,008
# New South Wales SA2 NAME                                                                        4,603,736
# 101021007       Braidwood                                                                           2,467
# 101021008       Karabar                                                                             5,103
# 101021009       Queanbeyan                                                                          7,028
#
#             Australian Bureau of Statistics                                               Unnamed: 3_level_0  \
# ...

# %% [markdown]
# ## Schools

# %%
SCHOOL_URL = "https://www.education.vic.gov.au/Documents/about/department/schoolsandenrolments.xlsx"

data = requests.get(SCHOOL_URL).content

# %% [markdown]
# - Didn't do this section as data is missing private schools
# - Also doesn't include location just name
# - Includes enrolment at the council level, but that's about all
