# %% [markdown]
# This notebook implements and evaluates different models for:
# - Predicting the yearly median rent given suburb, year and relevant suburban features,
# - Listing the top 10 suburbs with the highest predicted growth rate,
# - Figuring out the most liveable and affordable suburbs according to some metrics,
# - Predicting the rental price of a property given its attributes.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
# Read the median rent data
yearly_median = pd.read_csv('../data/curated/yearly_median_rent_by_suburb.csv')
yearly_median.head()
# Out:
#                                   suburb  year  median_rent  \
# 0  Albert Park-Middle Park-West St Kilda  2002          300
# 1                               Armadale  2002          233
# 2                          Carlton North  2002          290
# 3                      Carlton-Parkville  2002          270
# 4                        CBD-St Kilda Rd  2002          320
#
#    best_school_number_vce_subjects  \
# 0                             57.0
# 1                             30.0
# 2                             43.0
# 3                             61.0
# 4                              9.0
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           99.0
# 1                                          100.0
# 2                                           99.0
# 3                                           97.0
# 4                                          100.0
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                            31.0                                      6.3
# 1                            34.0                                     19.8
# 2                            31.0                                      0.0
# 3                            31.0                                     13.6
# 4                            29.0                                      5.7
#
#    best_school_percentage_applying_to_victorian_uni best_school_school_name  \
# 0                                              83.0     albert park college
# 1                                              97.0  lauriston girls school
# 2                                              78.0                     NaN
# 3                                              91.0  university high school
# 4                                              54.0   holmes grammar school
#
#    avg_school_number_vce_subjects  ...  b60_bribery  total_crimes  total_area  \
# 0                       57.000000  ...          0.0   2586.379367   7043125.0
# 1                       30.000000  ...          0.0    605.270037   2181875.0
# 2                       42.583333  ...          0.0    780.000033   2305625.0
# 3                       61.000000  ...          0.0   1749.415541   5855625.0
# 4                        9.000000  ...          0.0  10326.999768   2367500.0
#
#    developed_area  built_percentage  urban_percentage  disturbed_percentage  \
# 0       4691875.0          0.032212          0.595794              0.038158
# 1       2112500.0          0.026353          0.934403              0.007448
# 2       1977500.0          0.007861          0.843589              0.006235
# 3       4111875.0          0.066816          0.612766              0.022628
# 4       2187500.0          0.579461          0.287223              0.057286
#
#    water_percentage  developed_percentage nature_percentage
# 0          0.047387              0.666164          0.286450
# 1          0.000000              0.968204          0.031796
# 2          0.000000              0.857685          0.142315
# 3          0.000000              0.702209          0.297791
# 4          0.007656              0.923970          0.068374
#
# [5 rows x 61 columns]

# %%
# Normalize the numeric features
scaler = MinMaxScaler()
numeric_cols = yearly_median.select_dtypes(include=['float64', 'int64']).columns
yearly_median[numeric_cols] = scaler.fit_transform(yearly_median[numeric_cols])
yearly_median.head()
# Out:
#                                   suburb  year  median_rent  \
# 0  Albert Park-Middle Park-West St Kilda   0.0     0.303030
# 1                               Armadale   0.0     0.206349
# 2                          Carlton North   0.0     0.288600
# 3                      Carlton-Parkville   0.0     0.259740
# 4                        CBD-St Kilda Rd   0.0     0.331890
#
#    best_school_number_vce_subjects  \
# 0                         0.767123
# 1                         0.397260
# 2                         0.575342
# 3                         0.821918
# 4                         0.109589
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           0.96
# 1                                           1.00
# 2                                           0.96
# 3                                           0.88
# 4                                           1.00
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                        0.529412                                 0.137555
# 1                        0.705882                                 0.432314
# 2                        0.529412                                 0.000000
# 3                        0.529412                                 0.296943
# 4                        0.411765                                 0.124454
#
#    best_school_percentage_applying_to_victorian_uni best_school_school_name  \
# 0                                          0.773333     albert park college
# 1                                          0.960000  lauriston girls school
# 2                                          0.706667                     NaN
# 3                                          0.880000  university high school
# 4                                          0.386667   holmes grammar school
#
#    avg_school_number_vce_subjects  ...  b60_bribery  total_crimes  total_area  \
# 0                        0.859375  ...          0.0      0.205757    0.002199
# 1                        0.437500  ...          0.0      0.033086    0.000312
# 2                        0.634115  ...          0.0      0.048316    0.000360
# 3                        0.921875  ...          0.0      0.132808    0.001738
# 4                        0.109375  ...          0.0      0.880418    0.000384
#
#    developed_area  built_percentage  urban_percentage  disturbed_percentage  \
# 0        0.082507          0.055450          0.615293              0.174042
# 1        0.018526          0.045338          0.969952              0.033970
# 2        0.015177          0.013420          0.874834              0.028437
# 3        0.068120          0.115176          0.633069              0.103208
# 4        0.020386          1.000000          0.292095              0.261288
#
#    water_percentage  developed_percentage nature_percentage
# 0          0.321817              0.667721          0.285611
# 1          0.000000              0.974606          0.025526
# 2          0.000000              0.862314          0.138402
# 3          0.000000              0.704344          0.297194
# 4          0.051993              0.929663          0.062884
#
# [5 rows x 61 columns]

# %%
# Compute the Pearson's correlation between 'median_rent' and the other numeric features (excluding 'suburb')
# Assumptions: linearity, homoscedasticity
pearson_corr = yearly_median[numeric_cols].corr()['median_rent'].sort_values(ascending=False)
pearson_corr
# Out:
# median_rent                                            1.000000
# year                                                   0.730696
# developed_percentage                                   0.412972
# urban_percentage                                       0.371749
# avg_school_percentage_applying_to_victorian_uni        0.338044
# avg_school_median_study_score                          0.311855
# best_school_percentage_applying_to_victorian_uni       0.302528
# zoned_school_study_score_over_40_percent               0.275304
# best_school_median_study_score                         0.263954
# zoned_school_percentage_applying_to_victorian_uni      0.244467
# built_percentage                                       0.213614
# avg_school_satisfactory_complete_vce_percent           0.192729
# best_school_satisfactory_complete_vce_percent          0.187115
# avg_school_study_score_over_40_percent                 0.182035
# zoned_school_number_vce_subjects                       0.153939
# best_school_study_score_over_40_percent                0.138610
# f90_miscellaneous_offences                             0.131862
# avg_school_number_vce_subjects                         0.127989
# best_school_number_vce_subjects                        0.125431
# zoned_school_median_study_score                        0.124726
# disturbed_percentage                                   0.116686
# d20_disorderly_and_offensive_conduct                   0.089362
# d40_public_security_offences                           0.083393
# zoned_school_satisfactory_complete_vce_percent         0.080557
# water_percentage                                       0.059884
# f20_transport_regulation_offences                      0.033869
# f30_other_government_regulatory_offences               0.032712
# c90_other_drug_offences                                0.032140
# b50_deception                                          0.027155
# b60_bribery                                            0.013046
# a50_robbery                                            0.005923
# f10_regulatory_driving_offences                       -0.015286
# c10_drug_dealing_and_trafficking                      -0.057006
# b30_burglary/break_and_enter                          -0.071577
# c30_drug_use_and_possession                           -0.087541
# b40_theft                                             -0.096172
# d30_public_nuisance_offences                          -0.105091
# a20_assault_and_related_offences                      -0.151253
# total_crimes                                          -0.161114
# total_area                                            -0.162162
# d10_weapons_and_explosives_offences                   -0.172402
# b20_property_damage                                   -0.197769
# other_crimes_against_the_person                       -0.207630
# a70_stalking,_harassment_and_threatening_behaviour    -0.212361
# developed_area                                        -0.223977
# e10_justice_procedures                                -0.225309
# a80_dangerous_and_negligent_acts_endangering_people   -0.265007
# c20_cultivate_or_manufacture_drugs                    -0.270747
# b10_arson                                             -0.322482
# e20_breaches_of_orders                                -0.338725
# crow_distance_to_cbd                                  -0.392051
# distance_to_cbd                                       -0.392228
# duration_to_cbd                                       -0.399532
# nature_percentage                                     -0.418798
# Name: median_rent, dtype: float64

# %%
# Build a model to predict the yearly median rent given suburb, year and relevant suburban features
le = LabelEncoder()
X = yearly_median[['suburb'] + list(numeric_cols)]
X['suburb'] = le.fit_transform(X['suburb'])
y = yearly_median['median_rent']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30034)
# Out:
# /tmp/ipykernel_217493/3239761291.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['suburb'] = le.fit_transform(X['suburb'])

# %%
# Fit a baseline model
# In this case, choose a suburb-wise mean baseline
suburb_mean = yearly_median.groupby('suburb')['median_rent'].mean()
y_pred = X_test['suburb'].apply(lambda x: suburb_mean[x])
baseline_mse = mean_squared_error(y_test, y_pred)
print(f'Baseline MSE: {baseline_mse}')
# Out:
# Baseline MSE: 0.014167800924229788
# /tmp/ipykernel_217493/3752854163.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_pred = X_test['suburb'].apply(lambda x: suburb_mean[x])

# %%
# Fit a baseline model
# In this case, choose a year-wise mean baseline
year_mean = yearly_median.groupby('year')['median_rent'].mean()
y_pred = X_test['year'].apply(lambda x: year_mean[x])
baseline_mse = mean_squared_error(y_test, y_pred)
print(f'Baseline MSE: {baseline_mse}')
# Out:
# Baseline MSE: 0.011028198602621277

# %%
# Fit a linear regression model
LR = LinearRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean squared error: {mse}')
# Out:
# Mean squared error: 3.2996718483716504e-28

# %%
# Read the current listings data
domain_current = pd.read_parquet('../data/landing/cleaned_domain_current_listings.parquet')
domain_current.head()
# Out:
#    bedrooms  bathrooms  car_parks  \
# 0         2          1          1
# 1         3          2          2
# 2         3          2          1
# 3         2          1          1
# 4         3          2          2
#
#                                                  url  \
# 0  https://www.domain.com.au/705-8-marmion-place-...
# 1  https://www.domain.com.au/5-18-20-ibbottson-st...
# 2  https://www.domain.com.au/2109-35-malcolm-st-s...
# 3  https://www.domain.com.au/4-17a-the-esplanade-...
# 4  https://www.domain.com.au/501-446-malvern-road...
#
#                                           name         cost_text  \
# 0      705/8 Marmion Place, Docklands VIC 3008     $600 per week
# 1  5/18-20 Ibbottson Street, Watsonia VIC 3087     $650 Per Week
# 2     2109/35 Malcolm St, South Yarra VIC 3141       $1,150/week
# 3        4/17a The Esplanade, Geelong VIC 3220  $475.00 per week
# 4       501/446 Malvern Road, Prahran VIC 3181    $2200 Per Week
#
#                       type            latitude    longitude  \
# 0  Apartment / Unit / Flat         -37.8134708  144.9424794
# 1                Townhouse  -37.70987239999999  145.0844928
# 2  Apartment / Unit / Flat         -37.8369683  144.9964622
# 3  Apartment / Unit / Flat         -38.1345686  144.3548803
# 4  Apartment / Unit / Flat         -37.8479885  145.0012197
#
#                   suburb postcode  rent_pw
# 0     Docklands VIC 3008     3008      600
# 1      Watsonia VIC 3087     3087      650
# 2   South Yarra VIC 3141     3141     1150
# 3       Geelong VIC 3220     3220      475
# 4       Prahran VIC 3181     3181     2200

# %%
# Compute the Pearson's correlation between 'rent_pw' and the other numeric features
# Assumptions: linearity, homoscedasticity
pearson_corr = domain_current[['bedrooms', 'bathrooms', 'car_parks', 'rent_pw']].corr()['rent_pw'].sort_values(ascending=False)
pearson_corr
# Out:
# rent_pw      1.000000
# bathrooms    0.100481
# bedrooms     0.085069
# car_parks    0.068947
# Name: rent_pw, dtype: float64

# %%
# Build a model to predict the rental price of a property given its attributes
# including the postcode, type, number of bedrooms, number of bathrooms, and number of parking spaces
le = LabelEncoder()
X = domain_current[['postcode', 'type', 'bedrooms', 'bathrooms', 'car_parks']]
X['postcode'] = le.fit_transform(X['postcode'])
X['type'] = le.fit_transform(X['type'])
y = domain_current['rent_pw']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30034)
# Out:
# /tmp/ipykernel_217493/479912965.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['postcode'] = le.fit_transform(X['postcode'])
# /tmp/ipykernel_217493/479912965.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['type'] = le.fit_transform(X['type'])

# %%
# Use the dummy regressor as a baseline
from sklearn.dummy import DummyRegressor
DR = DummyRegressor(strategy='mean')
DR.fit(X_train, y_train)
y_pred = DR.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean squared error: {mse}')
# Out:
# Mean squared error: 2333467.754144234

# %%
# Fit a K-nearest neighbors regressor
from sklearn.neighbors import KNeighborsRegressor
KNR = KNeighborsRegressor(n_neighbors=5)
KNR.fit(X_train, y_train)
y_pred = KNR.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean squared error: {mse}')
# Out:
# Mean squared error: 1440777.9509677421
