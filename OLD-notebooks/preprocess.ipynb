# %% [markdown]
# This notebook preprocesses the current listings of domain and the historical suburban rent dataset.
#
# By running all the cells in this notebook, any cleaned dataset will be saved in either the landing or curated folder.

# %% [markdown]
# Before running this notebook, make sure you have:
# - 'domain_current_listings.parquet' and 'Moving annual rent by suburb - March quarter 2023.xlsx' in the raw folder,
# - 'schools_by_region.csv', 'distances.csv', 'crime.csv' and 'land_cover.csv' in the landing folder.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, regexp_extract, regexp_replace
import pandas as pd

# %%
# Create a SparkSession
spark = (SparkSession.builder.appName("Project 2")
         .config("spark.sql.repl.eagerEval.enabled", True)
         .config("spark.sql.parquet.cacheMetadata", "true")
         .config("spark.sql.session.timeZone", "Etc/UTC")
         .getOrCreate()
)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/10/05 19:29:44 WARN Utils: Your hostname, DESKTOP-JJQB7CC resolves to a loopback address: 127.0.1.1; using 172.30.3.30 instead (on interface eth0)
# 24/10/05 19:29:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/05 19:29:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read the parquet file 
domain_current = spark.read.parquet('../data/raw/domain_current_listings.parquet')
domain_current.limit(5)
# Out:
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+
# |bedrooms|bathrooms|car_parks|                 url|                name|       cost_text|                type|          latitude|  longitude|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+
# |       2|        1|        1|https://www.domai...|705/8 Marmion Pla...|   $600 per week|Apartment / Unit ...|       -37.8134708|144.9424794|
# |       3|        2|        2|https://www.domai...|5/18-20 Ibbottson...|   $650 Per Week|           Townhouse|-37.70987239999999|145.0844928|
# |       3|        2|        1|https://www.domai...|2109/35 Malcolm S...|     $1,150/week|Apartment / Unit ...|       -37.8369683|144.9964622|
# |       2|        1|        1|https://www.domai...|4/17a The Esplana...|$475.00 per week|Apartment / Unit ...|       -38.1345686|144.3548803|
# |       3|        2|        2|https://www.domai...|501/446 Malvern R...|  $2200 Per Week|Apartment / Unit ...|       -37.8479885|145.0012197|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+

# %%
# Count the number of properties
domain_current.count()
# Out:
# 14199

# %%
# Print the data types of the columns
domain_current.printSchema()
# Out:
# root
#  |-- bedrooms: integer (nullable = true)
#  |-- bathrooms: integer (nullable = true)
#  |-- car_parks: integer (nullable = true)
#  |-- url: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- cost_text: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)

# %%
# Dectect the rows that have missing values in the columns 'name', 'cost_text', 'type', 'latitude' and 'longitude'
domain_current.where(domain_current['name'].isNull()).count(), domain_current.where(domain_current['cost_text'].isNull()).count(), domain_current.where(domain_current['type'].isNull()).count(), domain_current.where(domain_current['latitude'].isNull()).count(), domain_current.where(domain_current['longitude'].isNull()).count()
# Out:
# (0, 0, 0, 0, 0)

# %%
# Drop the rows that have missing values in the columns 'bedrooms', 'bathrooms' and 'car_parks'
domain_current = domain_current.dropna(subset=['bedrooms', 'bathrooms', 'car_parks'])
domain_current.count()
# Out:
# 14166

# %%
# Creat a new column 'suburb' by extracting the suburbs from 'name'
domain_current = domain_current.withColumn('suburb', split(domain_current['name'], ',')[1])
domain_current.limit(5)
# Out:
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+
# |bedrooms|bathrooms|car_parks|                 url|                name|       cost_text|                type|          latitude|  longitude|              suburb|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+
# |       2|        1|        1|https://www.domai...|705/8 Marmion Pla...|   $600 per week|Apartment / Unit ...|       -37.8134708|144.9424794|  Docklands VIC 3008|
# |       3|        2|        2|https://www.domai...|5/18-20 Ibbottson...|   $650 Per Week|           Townhouse|-37.70987239999999|145.0844928|   Watsonia VIC 3087|
# |       3|        2|        1|https://www.domai...|2109/35 Malcolm S...|     $1,150/week|Apartment / Unit ...|       -37.8369683|144.9964622| South Yarra VIC ...|
# |       2|        1|        1|https://www.domai...|4/17a The Esplana...|$475.00 per week|Apartment / Unit ...|       -38.1345686|144.3548803|    Geelong VIC 3220|
# |       3|        2|        2|https://www.domai...|501/446 Malvern R...|  $2200 Per Week|Apartment / Unit ...|       -37.8479885|145.0012197|    Prahran VIC 3181|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+

# %%
# Create a new column 'postcode' by extracting the postcodes from 'suburb'
domain_current = domain_current.withColumn('postcode', regexp_extract(domain_current['suburb'], r'\b(\d{4})\b', 0))
domain_current.limit(5)
# Out:
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+--------+
# |bedrooms|bathrooms|car_parks|                 url|                name|       cost_text|                type|          latitude|  longitude|              suburb|postcode|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+--------+
# |       2|        1|        1|https://www.domai...|705/8 Marmion Pla...|   $600 per week|Apartment / Unit ...|       -37.8134708|144.9424794|  Docklands VIC 3008|    3008|
# |       3|        2|        2|https://www.domai...|5/18-20 Ibbottson...|   $650 Per Week|           Townhouse|-37.70987239999999|145.0844928|   Watsonia VIC 3087|    3087|
# |       3|        2|        1|https://www.domai...|2109/35 Malcolm S...|     $1,150/week|Apartment / Unit ...|       -37.8369683|144.9964622| South Yarra VIC ...|    3141|
# |       2|        1|        1|https://www.domai...|4/17a The Esplana...|$475.00 per week|Apartment / Unit ...|       -38.1345686|144.3548803|    Geelong VIC 3220|    3220|
# |       3|        2|        2|https://www.domai...|501/446 Malvern R...|  $2200 Per Week|Apartment / Unit ...|       -37.8479885|145.0012197|    Prahran VIC 3181|    3181|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+--------+

# %%
# Create a new column 'rent_pw' by extracting the rents from 'cost_text'
domain_current = domain_current.withColumn('rent_pw', regexp_extract(regexp_replace(domain_current['cost_text'], ',', ''), r'\b(\d+)\b', 0))
domain_current.limit(5)
# Out:
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+--------+-------+
# |bedrooms|bathrooms|car_parks|                 url|                name|       cost_text|                type|          latitude|  longitude|              suburb|postcode|rent_pw|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+--------+-------+
# |       2|        1|        1|https://www.domai...|705/8 Marmion Pla...|   $600 per week|Apartment / Unit ...|       -37.8134708|144.9424794|  Docklands VIC 3008|    3008|    600|
# |       3|        2|        2|https://www.domai...|5/18-20 Ibbottson...|   $650 Per Week|           Townhouse|-37.70987239999999|145.0844928|   Watsonia VIC 3087|    3087|    650|
# |       3|        2|        1|https://www.domai...|2109/35 Malcolm S...|     $1,150/week|Apartment / Unit ...|       -37.8369683|144.9964622| South Yarra VIC ...|    3141|   1150|
# |       2|        1|        1|https://www.domai...|4/17a The Esplana...|$475.00 per week|Apartment / Unit ...|       -38.1345686|144.3548803|    Geelong VIC 3220|    3220|    475|
# |       3|        2|        2|https://www.domai...|501/446 Malvern R...|  $2200 Per Week|Apartment / Unit ...|       -37.8479885|145.0012197|    Prahran VIC 3181|    3181|   2200|
# +--------+---------+---------+--------------------+--------------------+----------------+--------------------+------------------+-----------+--------------------+--------+-------+

# %%
# Convert the data type of 'rent_pw' to integer
domain_current = domain_current.withColumn('rent_pw', domain_current['rent_pw'].cast('int'))
domain_current.printSchema()
# Out:
# root
#  |-- bedrooms: integer (nullable = true)
#  |-- bathrooms: integer (nullable = true)
#  |-- car_parks: integer (nullable = true)
#  |-- url: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- cost_text: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- suburb: string (nullable = true)
#  |-- postcode: string (nullable = true)
#  |-- rent_pw: integer (nullable = true)

# %%
# Dectect the rows that have missing values in the column 'rent_pw'
domain_current.where(domain_current['rent_pw'].isNull()).count()
# Out:
# 838

# %%
# Drop the the rows that have missing values in the column 'rent_pw'
domain_current = domain_current.dropna(subset=['rent_pw'])
domain_current.count()
# Out:
# 13328

# %%
# Convert 'domain_current' to a pandas DataFrame
domain_current = domain_current.toPandas()

# %%
# Display the full list
pd.set_option('display.max_rows', None)

# Detect the rows with any 'annual' or 'month' or 'season' in 'cost_text'
domain_current[domain_current['cost_text'].str.contains('annual|month|season', case=False)]
# Out:
#        bedrooms  bathrooms  car_parks  \
# 20            3          2          0
# 25            3          2          2
# 37            4          2          2
# 154           0          1          0
# 351           2          2          1
# 360           3          2          1
# 363           4          2          2
# 473           0          1          1
# 540           4          3          1
# 836           3          1          1
# 839           3          1          1
# 927           0          1          1
# 1291          2          1          1
# 1294          2          1          0
# 1315          4          2          2
# 1341          4          2          2
# 1492          1          1          0
# 1762          2          1          1
# 1770          3          2          2
# 1783          1          1          1
# 1795          4          1          0
# 1827          4          2          2
# 1843          3          1          2
# 1845          3          2          2
# 1861          4          2          2
# 1912          4          2          2
# 1929          1          1          0
# 2308          2          2          1
# 2379          4          2          2
# 2683          2          1          0
# 2690          4          2          2
# 2692          4          2          2
# 2693          1          1          0
# 2695          3          1          1
# 2865          1          1          0
# 3144          2          2          0
# 3147          1          1          0
# 3164          3          1          4
# 3244          3          2          2
# 3423          4          2          2
# 3514          4          2          4
# 3736          2          1          0
# 3746          2          1          1
# 3747          1          1          0
# 3756          1          1          1
# 3770          4          2          2
# 3800          3          2          2
# 3813          2          1          0
# 3830          3          2          2
# 4004          3          2          3
# 4081          1          1          1
# 4235          3          1          2
# 4240          4          2          2
# 4263          4          1          2
# 4372          1          1          0
# 4446          3          2          3
# 4710          4          2          2
# 4874          4          2          2
# 5021          4          2          2
# 5156          1          1          0
# 5157          1          1          1
# 5166          2          1          1
# 5167          1          1          1
# 5638          3          2          2
# 5653          2          1          1
# 5767          4          2          2
# 6088          2          1          0
# 6115          4          2          4
# 6126          4          3          2
# 6145          3          2          2
# 6169          0          1          1
# 6223          1          1          0
# 6283          3          2          2
# 6553          2          1          1
# 6769          3          1          1
# 6969          2          1          0
# 6996          1          1          1
# 7136          4          2          2
# 7438          2          1          1
# 7463          3          1          1
# 7515          2          1          0
# 7554          3          1          0
# 7564          0          1          1
# 7657          4          2          2
# 7658          3          2          4
# 7910          2          1          2
# 7911          2          1          1
# 7979          2          1          0
# 8012          3          1          0
# 8501          0          1          1
# 8539          4          2          2
# 8852          4          2          2
# 9054          3          1          2
# 9322          1          1          1
# 9325          2          1          1
# 9341          2          1          1
# 11411     CAR PARK 2008/11 Rose Lane, Melbourne VIC 3000
# 11425           6 Willandra Boulevard, Harkness VIC 3337
# 11427       LOT 708/45 Clarke Street, Southbank VIC 3006
# 11536     Car Space/6 Leicester Street, Carlton VIC 3053
# 11664                53 Mitchell Street, Echuca VIC 3564
# 11864             3/59 Grantleigh Drive, Darley VIC 3340
# 11887                 4 Walter Street, Sunshine VIC 3020
# 11909         5 Rearden Crescent, Roxburgh Park VIC 3064
# 11998       367 Merriang South Road, Myrtleford VIC 3737
# 12448     carpark135 Abekcett Street, Melbourne VIC 3000
# 12571                45 McKinlay Street, Echuca VIC 3564
# 12798            303N/883 Collins St, Docklands VIC 3008
# 12811            2531 STEIGLITZ ROAD, Steiglitz VIC 3331
# 12818          42 Gibsons Circuit, Bonnie Brook VIC 3335
# 12826            2/3 Schuss Street, Falls Creek VIC 3699
# 12970                     1 Wagner Way, Aintree VIC 3336
# 12996                   635 Dalton Road, Epping VIC 3076
# 13288          211/40 Bush Boulevard, Mill Park VIC 3082
#
#                                                cost_text  \
# 20                Unfurnished Six Month Lease | $630 p/w
# 25                              $2173 per calendar month
# 37                          $510 per week/2216 per month
# 154                                     $1,500 per month
# 351             $860 per week / $3737 per calendar month
# 360     ENQUIRE NOW | $800 PER WEEK | $3477 P/MONTH/BOND
# 363             $520 per week / $2260 Per calendar month
# 473                                       $300 per month
# 540             $630 per week / $2738 per calendar month
# 836               $460 per week/$1999 per calendar month
# 839              $460 per week /$1999 per calendar month
# 927                                       $300 per month
# 1291           $580 per week | $2,520 per calendar month
# 1294             $650 per week, $2824 per calendar month
# 1315            $455 per week / $1977 per calendar month
# 1341                    $530 per week / $2,303 per month
# 1492                       $340 per week/$1477 per month
# 1762             $500 per week, $2173 per calendar month
# 1770            $750 Per Week - $3259 per calendar month
# 1783                     from $729 pw - 3 Month min Stay
# 1795                              $49,500 for the season
# 1827              4 Months fixed term lease only $450 pw
# 1843                     $570 per week, $2,477 per month
# 1845           $800 per week | $3,476 per calendar month
# 1861        $600 per week and $2,607 per calendar month.
# 1912                                RENT $2607 PER MONTH
# 1929                       $325 per month + initial bond
# 2308                                $2687 calendar month
# 2379                     $480 per week / $2086 per month
# 2683     $600 Per Week 6 Month Lease Partially Furnished
# 2690   ENQUIRE NOW | $540 PER WEEK | $2346 PER MONTH/...
# 2692            $520 per week / $2260 Per calendar month
# 2693                              $77 per calendar month
# 2695              $460 per week/$1999 per calendar month
# 2865                       $325 per month + initial bond
# 3144             $770 per week, $3346 per calendar month
# 3147             $440 per week, $1912 per calendar month
# 3164           $580 per week | $2,520 per calendar month
# 3244             $520 per week /$2260 per calendar month
# 3423                       $480 per week/$2086 per month
# 3514                            $2607 per calander month
# 3736             $650 per week, $2824 per calendar month
# 3746            $350 per week / $1521 per calendar month
# 3747             $440 per week, $1912 per calendar month
# 3756                                      $220 per month
# 3770          $ 490 per week / $ 2129 per calendar month
# 3800           $730 per week | $3,172 per calendar month
# 3813                                     $2390 per month
# 3830             $520 per week /$2260 per calendar month
# 4004                                $1950 calendar month
# 4081                                      $150 per month
# 4235   ENQUIRE NOW | $510 PER WEEK | $2217 PER MONTH/...
# 4240          $ 490 per week / $ 2129 per calendar month
# 4263            $440 per week / $1912 per calendar month
# 4372                   $ 125 To $ 190 Per Calendar Month
# 4446                            $1955 per calander month
# 4710            $580 Per Week / $2520 Per Calendar Month
# 4874                           $600 p/w ($2,607 monthly)
# 5021                                $2730 calendar month
# 5156        $530 per week and $2,303 per calendar month.
# 5157        $500 per week and $2,173 per calendar month.
# 5166                    $525 per week - 6 month lease pw
# 5167                                      $220 per month
# 5638            $580 per week / $2520 Per calendar month
# 5653                     $480 per week / $2086 per month
# 5767                      $560 per week/ $2433 per month
# 6088             $690 per week, $2998 per calendar month
# 6115            $500 per week / $2173 per calendar month
# 6126                     $530 per week / $2303 per month
# 6145           $730 per week | $3,172 per calendar month
# 6169                                          $250/month
# 6223                                 From $110 per month
# 6283                      $500 per week/ $2173 per month
# 6553        $680 per week and $2,955 per calendar month.
# 6769                                $1820 calendar month
# 6969             $650 per week, $2824 per calendar month
# 6996                                      $230 per month
# 7136                     $480 per week / $2086 per month
# 7438             $500 per week, $2173 per calendar month
# 7463             $460 per week /$1999 per calendar month
# 7515                                     $2390 per month
# 7554               $420.00 per week - 6 Month Lease Only
# 7564                                      $300 per month
# 7657                           $800 1,2 or 3 Month Lease
# 7658                           $45,000 for winter season
# 7910           $670 per week | $2,911 per calendar month
# 7911           $580 per week | $2,520 per calendar month
# 7979                                     $2390 per month
# 8012               $420.00 per week - 6 Month Lease Only
# 8501                                      $250 per month
# 8539                       $480 per week/$2086 per month
# 8852   ENQUIRE NOW | $540 PER WEEK | $2346 PER MONTH/...
# 9054                      $450 per week/ $1955 per month
# 9322        $500 per week and $2,173 per calendar month.
# 9325            $350 per week / $1521 per calendar month
# 9341                    $525 per week - 6 month lease pw
# 9348            $430 per week / $1868 per calendar month
# 9351                              $49,500 for the season
# 9426        $600 per week and $2,607 per calendar month.
# 9793                     $480 per week / $2086 per month
# 9802          $450 per week / $1,955 per calendar monthh
# 9808                                       $3200 monthly
# 10029           $440 per week / $1912 per calendar month
# 10041             $550 per week/$2390 per calendar month
# 10117                    $900 Per Week / $3911 Per Month
# 10456            $650 per week, $2824 per calendar month
# 10467           $520 per week / $2260 Per calendar month
# 10472           $600 per week / $2607 per calendar month
# 10536                          $280 pw / $1216 per month
# 10585                          $45,000 for winter season
# 10606                    $480 per week / $2086 per month
# 10613                       $510 per week/2216 per month
# 10684                               $2687 calendar month
# 10929       $680 per week and $2,955 per calendar month.
# 10973           $470 per week / $2042 per calendar month
# 10976         $450 per week / $1,955 per calendar monthh
# 11008                    $570 per week, $2,477 per month
# 11143                           $1955 per calander month
# 11389            $500 per week, $2173 per calendar month
# 11411                                     $230 per month
# 11425           $500 per week / $2173 per calendar month
# 11427                                     $260 per month
# 11536                                     $240 per month
# 11664                               $1820 calendar month
# 11864           $420 per week / $1825 per calendar month
# 11887  ENQUIRE NOW | $510 PER WEEK | $2217 PER MONTH/...
# 11909                   $530 per week / $2,303 per month
# 11998                                From $110 per month
# 11536            Carlton VIC 3053     3053      240
# 11664             Echuca VIC 3564     3564     1820
# 11864             Darley VIC 3340     3340      420
# 11887           Sunshine VIC 3020     3020      510
# 11909      Roxburgh Park VIC 3064     3064      530
# 11998         Myrtleford VIC 3737     3737      110
# 12448          Melbourne VIC 3000     3000      300
# 12571             Echuca VIC 3564     3564     2167
# 12798          Docklands VIC 3008     3008      530
# 12811          Steiglitz VIC 3331     3331     1275
# 12818       Bonnie Brook VIC 3335     3335      520
# 12826        Falls Creek VIC 3699     3699    49500
# 12970            Aintree VIC 3336     3336      630
# 12996             Epping VIC 3076     3076     2216
# 13288          Mill Park VIC 3082     3082      490

# %%
# Manually correct 'rent_pw'
domain_current.loc[25, 'rent_pw'] = 507
domain_current.loc[154, 'rent_pw'] = 350
domain_current.loc[473, 'rent_pw'] = 70
domain_current.loc[927, 'rent_pw'] = 70
domain_current.loc[1795, 'rent_pw'] = 3850
domain_current.loc[1827, 'rent_pw'] = 450
domain_current.loc[1912, 'rent_pw'] = 608
domain_current.loc[1929, 'rent_pw'] = 76
domain_current.loc[2308, 'rent_pw'] = 627
domain_current.loc[2693, 'rent_pw'] = 18
domain_current.loc[2865, 'rent_pw'] = 76
domain_current.loc[3514, 'rent_pw'] = 608
domain_current.loc[3756, 'rent_pw'] = 51
domain_current.loc[3813, 'rent_pw'] = 558
domain_current.loc[4004, 'rent_pw'] = 455
domain_current.loc[4081, 'rent_pw'] = 35
domain_current.loc[4372, 'rent_pw'] = 29
domain_current.loc[4446, 'rent_pw'] = 456
domain_current.loc[5021, 'rent_pw'] = 637
domain_current.loc[5167, 'rent_pw'] = 51
domain_current.loc[6169, 'rent_pw'] = 58
domain_current.loc[6223, 'rent_pw'] = 26
domain_current.loc[6769, 'rent_pw'] = 425
domain_current.loc[6996, 'rent_pw'] = 54
domain_current.loc[7515, 'rent_pw'] = 558
domain_current.loc[7564, 'rent_pw'] = 70
domain_current.loc[7658, 'rent_pw'] = 3500
domain_current.loc[7979, 'rent_pw'] = 558
domain_current.loc[8501, 'rent_pw'] = 58
domain_current.loc[9351, 'rent_pw'] = 3850
domain_current.loc[9808, 'rent_pw'] = 747
domain_current.loc[10585, 'rent_pw'] = 3500
domain_current.loc[10684, 'rent_pw'] = 627
domain_current.loc[11143, 'rent_pw'] = 456
domain_current.loc[11411, 'rent_pw'] = 54
domain_current.loc[11427, 'rent_pw'] = 61
domain_current.loc[11536, 'rent_pw'] = 56
domain_current.loc[11664, 'rent_pw'] = 425
domain_current.loc[11998, 'rent_pw'] = 26
domain_current.loc[12448, 'rent_pw'] = 70
domain_current.loc[12571, 'rent_pw'] = 506
domain_current.loc[12826, 'rent_pw'] = 3850
domain_current.loc[12996, 'rent_pw'] = 517

# %%
# List all the types of properties
domain_current['type'].unique()
# Out:
# array(['Apartment / Unit / Flat', 'Townhouse', 'House', 'Studio', 'Villa',
#        'Terrace', 'Duplex', 'Carspace', 'New House & Land',
#        'Semi-Detached', 'Acreage / Semi-Rural',
#        'New Apartments / Off the Plan', 'New land', 'Block of Units'],
#       dtype=object)

# %%
# Remove the rows with 'Carspace' in 'type'
domain_current = domain_current[~domain_current['type'].str.contains('Carspace', case=False)]

# %%
# Save the cleaned data to a parquet file
domain_current = spark.createDataFrame(domain_current)
domain_current.write.mode('overwrite').parquet('../data/landing/cleaned_domain_current_listings.parquet')
# Out:
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 75.08% for 9 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 67.58% for 10 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 61.43% for 11 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 56.31% for 12 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 51.98% for 13 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 48.27% for 14 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 45.05% for 15 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 42.24% for 16 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 45.05% for 15 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 48.27% for 14 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 51.98% for 13 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 56.31% for 12 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 61.43% for 11 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 67.58% for 10 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 75.08% for 9 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 24/10/05 19:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %%
# Read the last page of the xlsx file
historical_rent = pd.read_excel('../data/raw/Moving annual rent by suburb - March quarter 2023.xlsx', sheet_name='All properties')
historical_rent.head()
# Out:
#   Moving annual rent by suburb                             Unnamed: 1  \
# 0               All properties                                    NaN
# 1                          NaN                                    NaN
# 2              Inner Melbourne  Albert Park-Middle Park-West St Kilda
# 3                          NaN                               Armadale
# 4                          NaN                          Carlton North
#
#   Lease commenced in year ending  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                        Mar 2000        NaN   Jun 2000        NaN   Sep 2000
# 1                           Count     Median      Count     Median      Count
# 2                            1143        260       1134        260       1177
# 3                             733        200        737        200        738
# 4                             864        260        814        260        799
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 178 Unnamed: 179  \
# 0        NaN   Dec 2000        NaN  ...     Mar 2022          NaN
# 1     Median      Count     Median  ...        Count       Median
# 2        270       1178        275  ...          867          500
# 3        205        739        210  ...          805          430
# 4        265        736        270  ...          581          580
#
#   Unnamed: 180 Unnamed: 181 Unnamed: 182 Unnamed: 183 Unnamed: 184  \
# 0     Jun 2022          NaN     Sep 2022          NaN     Dec 2022
# 1        Count       Median        Count       Median        Count
# 2          855          515          881          500          832
# 3          851          450          852          450          840
# 4          535          595          547          600          546
#
#   Unnamed: 185 Unnamed: 186 Unnamed: 187
# 0          NaN     Mar 2023          NaN
# 1       Median        Count       Median
# 2          525          786          545
# 3          460          751          490
# 4          600          490          620
#
# [5 rows x 188 columns]

# %%
# Drop the columns from 'Lease commenced in year ending' to 'Unnamed: 17' (years before 2002 with some missing values) and the fisrt column (irrelevant granular information)
historical_rent = historical_rent.drop(columns=historical_rent.columns[2:18])
historical_rent = historical_rent.drop(columns=historical_rent.columns[0])
historical_rent.head()
# Out:
#                               Unnamed: 1 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0                                    NaN    Mar 2002         NaN    Jun 2002
# 1                                    NaN       Count      Median       Count
# 2  Albert Park-Middle Park-West St Kilda        1332         300        1350
# 3                               Armadale         774         233         783
# 4                          Carlton North         626         290         647
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0         NaN    Sep 2002         NaN    Dec 2003         NaN    Mar 2003
# 1      Median       Count      Median       Count      Median       Count
# 2         300        1415         300        1431         300        1422
# 3         230         773         230         724         230         747
# 4         290         644         290         670         290         685
#
#    ... Unnamed: 178 Unnamed: 179 Unnamed: 180 Unnamed: 181 Unnamed: 182  \
# 0  ...     Mar 2022          NaN     Jun 2022          NaN     Sep 2022
# 1  ...        Count       Median        Count       Median        Count
# 2  ...          867          500          855          515          881
# 3  ...          805          430          851          450          852
# 4  ...          581          580          535          595          547
#
#   Unnamed: 183 Unnamed: 184 Unnamed: 185 Unnamed: 186 Unnamed: 187
# 0          NaN     Dec 2022          NaN     Mar 2023          NaN
# 1       Median        Count       Median        Count       Median
# 2          500          832          525          786          545
# 3          450          840          460          751          490
# 4          600          546          600          490          620
#
# [5 rows x 171 columns]

# %%
# Dorp the even columns (count information)
#historical_median = historical_rent.iloc[:, ::2]
#historical_median.head()

# %%
# Drop the first two rows and reset the index
historical_median = historical_rent.drop([0, 1]).reset_index(drop=True)
historical_median.head()
# Out:
#                               Unnamed: 1 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0  Albert Park-Middle Park-West St Kilda        1332         300        1350
# 1                               Armadale         774         233         783
# 2                          Carlton North         626         290         647
# 3                      Carlton-Parkville        1305         270        1262
# 4                        CBD-St Kilda Rd        3316         320        3418
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0         300        1415         300        1431         300        1422
# 1         230         773         230         724         230         747
# 2         290         644         290         670         290         685
# 3         270        1267         275        1227         280        1297
# 4         320        3393         320        3404         320        3755
#
#    ... Unnamed: 178 Unnamed: 179 Unnamed: 180 Unnamed: 181 Unnamed: 182  \
# 0  ...          867          500          855          515          881
# 1  ...          805          430          851          450          852
# 2  ...          581          580          535          595          547
# 3  ...         6143          310         6018          319         6871
# 4  ...        17845          365        16792          390        18284
#
#   Unnamed: 183 Unnamed: 184 Unnamed: 185 Unnamed: 186 Unnamed: 187
# 0          500          832          525          786          545
# 1          450          840          460          751          490
# 2          600          546          600          490          620
# 3          340         6627          350         6690          400
# 4          419        17627          450        17426          500
#
# [5 rows x 171 columns]

# %%
# Rename the column 'Unnamed: 19' as '2002-03' and the rest of the columns in the format of 'year-month' as each quarter
historical_median.columns = ['suburb', 'count_2002-03', '2002-03', 'count_2002-06', '2002-06', 'count_2002-09', '2002-09', 'count_2002-12', '2002-12', 
                             'count_2003-03', '2003-03', 'count_2003-06', '2003-06', 'count_2003-09', '2003-09', 'count_2003-12', '2003-12', 
                             'count_2004-03', '2004-03', 'count_2004-06', '2004-06', 'count_2004-09', '2004-09', 'count_2004-12', '2004-12', 
                             'count_2005-03', '2005-03', 'count_2005-06', '2005-06', 'count_2005-09', '2005-09', 'count_2005-12', '2005-12', 
                             'count_2006-03', '2006-03', 'count_2006-06', '2006-06', 'count_2006-09', '2006-09', 'count_2006-12', '2006-12', 
                             'count_2007-03', '2007-03', 'count_2007-06', '2007-06', 'count_2007-09', '2007-09', 'count_2007-12', '2007-12', 
                             'count_2008-03', '2008-03', 'count_2008-06', '2008-06', 'count_2008-09', '2008-09', 'count_2008-12', '2008-12', 
                             'count_2009-03', '2009-03', 'count_2009-06', '2009-06', 'count_2009-09', '2009-09', 'count_2009-12', '2009-12', 
                             'count_2010-03', '2010-03', 'count_2010-06', '2010-06', 'count_2010-09', '2010-09', 'count_2010-12', '2010-12', 
                             'count_2011-03', '2011-03', 'count_2011-06', '2011-06', 'count_2011-09', '2011-09', 'count_2011-12', '2011-12', 
                             'count_2012-03', '2012-03', 'count_2012-06', '2012-06', 'count_2012-09', '2012-09', 'count_2012-12', '2012-12', 
                             'count_2013-03', '2013-03', 'count_2013-06', '2013-06', 'count_2013-09', '2013-09', 'count_2013-12', '2013-12', 
                             'count_2014-03', '2014-03', 'count_2014-06', '2014-06', 'count_2014-09', '2014-09', 'count_2014-12', '2014-12', 
                             'count_2015-03', '2015-03', 'count_2015-06', '2015-06', 'count_2015-09', '2015-09', 'count_2015-12', '2015-12', 
                             'count_2016-03', '2016-03', 'count_2016-06', '2016-06', 'count_2016-09', '2016-09', 'count_2016-12', '2016-12', 
                             'count_2017-03', '2017-03', 'count_2017-06', '2017-06', 'count_2017-09', '2017-09', 'count_2017-12', '2017-12', 
                             'count_2018-03', '2018-03', 'count_2018-06', '2018-06', 'count_2018-09', '2018-09', 'count_2018-12', '2018-12', 
                             'count_2019-03', '2019-03', 'count_2019-06', '2019-06', 'count_2019-09', '2019-09', 'count_2019-12', '2019-12', 
                             'count_2020-03', '2020-03', 'count_2020-06', '2020-06', 'count_2020-09', '2020-09', 'count_2020-12', '2020-12', 
                             'count_2021-03', '2021-03', 'count_2021-06', '2021-06', 'count_2021-09', '2021-09', 'count_2021-12', '2021-12', 
                             'count_2022-03', '2022-03', 'count_2022-06', '2022-06', 'count_2022-09', '2022-09', 'count_2022-12', '2022-12', 
                             'count_2023-03', '2023-03']
historical_median.head()
# Out:
#                                   suburb count_2002-03 2002-03 count_2002-06  \
# 0  Albert Park-Middle Park-West St Kilda          1332     300          1350
# 1                               Armadale           774     233           783
# 2                          Carlton North           626     290           647
# 3                      Carlton-Parkville          1305     270          1262
# 4                        CBD-St Kilda Rd          3316     320          3418
#
#   2002-06 count_2002-09 2002-09 count_2002-12 2002-12 count_2003-03  ...  \
# 0     300          1415     300          1431     300          1422  ...
# 1     230           773     230           724     230           747  ...
# 2     290           644     290           670     290           685  ...
# 3     270          1267     275          1227     280          1297  ...
# 4     320          3393     320          3404     320          3755  ...
#
#   count_2022-03 2022-03 count_2022-06 2022-06 count_2022-09 2022-09  \
# 0           867     500           855     515           881     500
# 1           805     430           851     450           852     450
# 2           581     580           535     595           547     600
# 3          6143     310          6018     319          6871     340
# 4         17845     365         16792     390         18284     419
#
#   count_2022-12 2022-12 count_2023-03 2023-03
# 0           832     525           786     545
# 1           840     460           751     490
# 2           546     600           490     620
# 3          6627     350          6690     400
# 4         17627     450         17426     500
#
# [5 rows x 171 columns]

# %%
# Drop the rows 'Group Total'
historical_median = historical_median[~historical_median['suburb'].str.contains('Group Total')]

# %%
# Spelling correction
historical_median['suburb'] = historical_median['suburb'].replace('Wanagaratta', 'Wangaratta')
historical_median['suburb'] = historical_median['suburb'].replace('Newcombe', 'Newcomb')

# %%
# Save it to a csv file
historical_median.to_csv('../data/curated/historical_median_rent_by_suburb.csv', index=False)

# %%
# Create a new dataframe which only contains the median rent for the first quarter of each year as the median rent for the year
yearly_median = historical_median[['suburb', '2002-03', '2003-03', '2004-03', '2005-03', '2006-03', '2007-03', '2008-03', '2009-03', '2010-03', '2011-03', '2012-03', '2013-03', '2014-03', '2015-03', '2016-03', '2017-03', '2018-03', '2019-03', '2020-03', '2021-03', '2022-03', '2023-03']]

# Rename the columns
yearly_median.columns = ['suburb', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
yearly_median.head()
# Out:
#                                   suburb 2002 2003 2004 2005 2006 2007 2008  \
# 0  Albert Park-Middle Park-West St Kilda  300  295  300  300  313  345  380
# 1                               Armadale  233  235  240  240  250  280  320
# 2                          Carlton North  290  290  298  300  320  330  380
# 3                      Carlton-Parkville  270  280  285  281  275  275  290
# 4                        CBD-St Kilda Rd  320  310  300  300  310  340  370
#
#   2009 2010  ... 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023
# 0  410  425  ...  460  480  520  520  550  552  600  500  500  545
# 1  350  360  ...  390  400  400  420  480  480  500  450  430  490
# 2  400  420  ...  510  530  530  530  562  580  585  580  580  620
# 3  310  340  ...  355  351  373  395  410  435  404  350  310  400
# 4  400  410  ...  430  440  450  470  495  500  510  380  365  500
#
# [5 rows x 23 columns]

# %%
# Compute the yearly growth rate of the median rent for each suburb
yearly_growth = pd.DataFrame(yearly_median['suburb'])
for i in range(1, len(yearly_median.columns)-1):
    yearly_growth[str(2002+i)] = ((yearly_median[yearly_median.columns[i+1]] - yearly_median[yearly_median.columns[i]]) / yearly_median[yearly_median.columns[i]]) * 100

# Melt the dataframe to have the columns 'suburb', 'year' and 'growth_rate'
yearly_growth = yearly_growth.melt(id_vars='suburb', var_name='year', value_name='growth_rate')

# Convert the data type of 'year' to integer and 'growth_rate' to float
yearly_growth['year'] = yearly_growth['year'].astype('int')
yearly_growth['growth_rate'] = yearly_growth['growth_rate'].astype('float')
yearly_growth.head()
# Out:
#                                   suburb  year  growth_rate
# 0  Albert Park-Middle Park-West St Kilda  2003    -1.666667
# 1                               Armadale  2003     0.858369
# 2                          Carlton North  2003     0.000000
# 3                      Carlton-Parkville  2003     3.703704
# 4                        CBD-St Kilda Rd  2003    -3.125000

# %%
# Save it to a csv file
yearly_growth.to_csv('../data/curated/yearly_growth_rate_of_median_rent_by_suburb.csv', index=False)

# %%
# Melt the dataframe to have the columns 'suburb', 'year' and 'median_rent'
yearly_median = yearly_median.melt(id_vars='suburb', var_name='year', value_name='median_rent')

# Convert the data type of 'year' to integer and 'growth_rate' to integer
yearly_median['year'] = yearly_median['year'].astype('int')
yearly_median['median_rent'] = yearly_median['median_rent'].astype('int')
yearly_median.head()
# Out:
#                                   suburb  year  median_rent
# 0  Albert Park-Middle Park-West St Kilda  2002          300
# 1                               Armadale  2002          233
# 2                          Carlton North  2002          290
# 3                      Carlton-Parkville  2002          270
# 4                        CBD-St Kilda Rd  2002          320

# %%
# Number of suburbs in 'yearly_median'
yearly_median['suburb'].nunique()
# Out:
# 146

# %%
# Read 'schools_by_region.csv'
schools_by_region = pd.read_csv('../data/landing/schools_by_region.csv')
schools_by_region.head()
# Out:
#    best_school_number_vce_subjects  \
# 0                             57.0
# 1                             50.0
# 2                             30.0
# 3                             55.0
# 4                             45.0
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           99.0
# 1                                           99.0
# 2                                          100.0
# 3                                           96.0
# 4                                           95.0
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                            31.0                                      6.3
# 1                            30.0                                      7.8
# 2                            34.0                                     19.8
# 3                            30.0                                      6.4
# 4                            28.0                                      3.0
#
#    best_school_percentage_applying_to_victorian_uni  \
# 0                                              83.0
# 1                                              84.0
# 2                                              97.0
# 3                                              65.0
# 4                                              38.0
#
#                                  suburbs        best_school_school_name  \
# 0  Albert Park-Middle Park-West St Kilda            albert park college
# 1                                 Altona  mount st joseph girls college
# 2                               Armadale         lauriston girls school
# 3               Aspendale-Chelsea-Carrum             mordialloc college
# 4                             Bairnsdale                  nagle college
#
#    avg_school_number_vce_subjects  \
# 0                            57.0
# 1                            46.0
# 2                            30.0
# 3                            55.0
# 4                            46.5
#
#    avg_school_satisfactory_complete_vce_percent  \
# 0                                          99.0
# 1                                          99.5
# 2                                         100.0
# 3                                          96.0
# 4                                          97.0
#
#    avg_school_median_study_score  avg_school_study_score_over_40_percent  \
# 0                          31.00                                   6.300
# 1                          28.75                                   4.675
# 2                          34.00                                  19.800
# 3                          30.00                                   6.400
# 4                          27.00                                   1.900
#
#    avg_school_percentage_applying_to_victorian_uni  \
# 0                                             83.0
# 1                                             69.5
# 2                                             97.0
# 3                                             65.0
# 4                                             38.0
#
#    zoned_school_number_vce_subjects  \
# 0                         50.954001
# 1                         11.841528
# 2                         32.206598
# 3                         18.976452
# 4                         48.000000
#
#    zoned_school_satisfactory_complete_vce_percent  \
# 0                                       98.480180
# 1                                       45.544337
# 2                                       98.164926
# 3                                       33.122534
# 4                                       99.000000
#
#    zoned_school_median_study_score  zoned_school_study_score_over_40_percent  \
# 0                        30.937726                                  6.764547
# 1                        12.752414                                  0.500988
# 2                        31.139504                                  7.744409
# 3                        10.350792                                  2.208169
# 4                        26.000000                                  0.800000
#
#    zoned_school_percentage_applying_to_victorian_uni
# 0                                          78.993583
# 1                                          27.782046
# 2                                          92.199390
# 3                                          22.426716
# 4                                          38.000000

# %%
# Number of suburbs in 'schools_by_region'
schools_by_region['suburbs'].nunique()
# Out:
# 144

# %%
# Dectect the differed suburbs between 'yearly_median' and 'schools_by_region'
suburbs_diff = set(yearly_median['suburb']) - set(schools_by_region['suburbs'])
suburbs_diff
# Out:
# {'North Bendigo', 'Yarra Ranges'}

# %%
# Remove the differed suburbs from 'yearly_median'
yearly_median = yearly_median[~yearly_median['suburb'].isin(suburbs_diff)]
yearly_median['suburb'].nunique()
# Out:
# 144

# %%
# Impute NaN values using the median for each column respectively except 'suburbs' and 'best_school_school_name'
for column in schools_by_region.columns:
    if schools_by_region[column].dtype in ['float64', 'int64']:
        schools_by_region[column] = schools_by_region[column].fillna(schools_by_region[column].median())

# %%
# Join 'yearly_median' and 'schools_by_region'
yearly_median = yearly_median.merge(schools_by_region, left_on='suburb', right_on='suburbs', how='left')
yearly_median = yearly_median.drop(columns=['suburbs'])
yearly_median.head()
# Out:
#                                   suburb  year  median_rent  \
# 0  Albert Park-Middle Park-West St Kilda  2002          300
# 1                               Armadale  2002          233
# 2                          Carlton North  2002          290
# 3                      Carlton-Parkville  2002          270
# 4                        CBD-St Kilda Rd  2002          320
#
#    best_school_number_vce_subjects  \
# 0                             57.0
# 1                             30.0
# 2                             43.0
# 3                             61.0
# 4                              9.0
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           99.0
# 1                                          100.0
# 2                                           99.0
# 3                                           97.0
# 4                                          100.0
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                            31.0                                      6.3
# 1                            34.0                                     19.8
# 2                            31.0                                      0.0
# 3                            31.0                                     13.6
# 4                            29.0                                      5.7
#
#    best_school_percentage_applying_to_victorian_uni best_school_school_name  \
# 0                                              83.0     albert park college
# 1                                              97.0  lauriston girls school
# 2                                              78.0                     NaN
# 3                                              91.0  university high school
# 4                                              54.0   holmes grammar school
#
#    avg_school_number_vce_subjects  \
# 0                       57.000000
# 1                       30.000000
# 2                       42.583333
# 3                       61.000000
# 4                        9.000000
#
#    avg_school_satisfactory_complete_vce_percent  \
# 0                                          99.0
# 1                                         100.0
# 2                                          98.0
# 3                                          97.0
# 4                                         100.0
#
#    avg_school_median_study_score  avg_school_study_score_over_40_percent  \
# 0                           31.0                                     6.3
# 1                           34.0                                    19.8
# 2                           29.0                                     0.0
# 3                           31.0                                    13.6
# 4                           29.0                                     5.7
#
#    avg_school_percentage_applying_to_victorian_uni  \
# 0                                             83.0
# 1                                             97.0
# 2                                             71.0
# 3                                             91.0
# 4                                             54.0
#
#    zoned_school_number_vce_subjects  \
# 0                         50.954001
# 1                         32.206598
# 2                          5.112352
# 3                         39.920190
# 4                         58.909005
#
#    zoned_school_satisfactory_complete_vce_percent  \
# 0                                       98.480180
# 1                                       98.164926
# 2                                        8.978268
# 3                                       64.324368
# 4                                       94.839003
#
#    zoned_school_median_study_score  zoned_school_study_score_over_40_percent  \
# 0                        30.937726                                  6.764547
# 1                        31.139504                                  7.744409
# 2                         2.652416                                  0.834947
# 3                        20.390769                                  8.240293
# 4                        29.617576                                 11.796245
#
#    zoned_school_percentage_applying_to_victorian_uni
# 0                                          78.993583
# 1                                          92.199390
# 2                                           7.270972
# 3                                          58.750247
# 4                                          85.339400

# %%
# Read 'distances.csv'
distances_cbd = pd.read_csv('../data/landing/distances.csv')
distances_cbd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                             geometry  \
# 0  POLYGON ((144.97018001032677 -37.8606998481848...
# 1  POLYGON ((144.79015492149858 -37.8621593959499...
# 2  POLYGON ((145.01167433388778 -37.8535692509816...
# 3  POLYGON ((145.12548797012727 -38.0713448001564...
# 4  POLYGON ((147.57603348437306 -37.8302200300307...
#
#                                  suburbs  \
# 0  Albert Park-Middle Park-West St Kilda
# 1                                 Altona
# 2                               Armadale
# 3               Aspendale-Chelsea-Carrum
# 4                             Bairnsdale
#
#                                              regions  \
# 0                 ['Albert Park', 'St Kilda - West']
# 1                         ['Altona', 'Altona North']
# 2                                       ['Armadale']
# 3  ['Carrum - Patterson Lakes', 'Edithvale - Aspe...
# 4                                     ['Bairnsdale']
#
#                                 code  \
# 0             [206051128, 206051514]
# 1             [213021341, 213021343]
# 2                        [206061135]
# 3  [208031189, 208031186, 208031185]
# 4                        [205021081]
#
#                                         centroid  crow_distance_to_cbd  \
# 0  POINT (144.96815606060912 -37.85090369821219)              4.535857
# 1  POINT (144.82508757350203 -37.84854737942177)             12.833585
# 2   POINT (145.02071077926166 -37.8567469622587)              7.261986
# 3  POINT (145.12447097971767 -38.05297911022852)             30.465132
# 4   POINT (147.61398934302346 -37.8291507833843)            233.444538
#
#    distance_to_cbd  duration_to_cbd  \
# 0           6702.5            811.4
# 1          17936.7           1656.4
# 2          10138.0           1002.8
# 3          50846.3           2914.2
# 4         279492.3          12766.0
#
#                                         route_to_cbd
# 0  [[144.967419, -37.851489], [144.967423, -37.85...
# 1  [[144.825016, -37.848943], [144.825517, -37.84...
# 2  [[145.020491, -37.856724], [145.020572, -37.85...
# 3  [[145.124414, -38.052875], [145.126879, -38.05...
# 4  [[147.613996, -37.829069], [147.614083, -37.82...

# %%
# Drop the columns 'Unnamed: 0' and 'Unnamed: 1'
distances_cbd = distances_cbd.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# Detect missing values
distances_cbd.isnull().sum()
# Out:
# geometry                0
# suburbs                 0
# regions                 0
# code                    0
# centroid                0
# crow_distance_to_cbd    0
# distance_to_cbd         0
# duration_to_cbd         0
# route_to_cbd            0
# dtype: int64

# %%
# Join 'yearly_median' and 'distances_cbd'
yearly_median = yearly_median.merge(distances_cbd, left_on='suburb', right_on='suburbs', how='left')
yearly_median = yearly_median.drop(columns=['suburbs'])
yearly_median.head()
# Out:
#                                   suburb  year  median_rent  \
# 0  Albert Park-Middle Park-West St Kilda  2002          300
# 1                               Armadale  2002          233
# 2                          Carlton North  2002          290
# 3                      Carlton-Parkville  2002          270
# 4                        CBD-St Kilda Rd  2002          320
#
#    best_school_number_vce_subjects  \
# 0                             57.0
# 1                             30.0
# 2                             43.0
# 3                             61.0
# 4                              9.0
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           99.0
# 1                                          100.0
# 2                                           99.0
# 3                                           97.0
# 4                                          100.0
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                            31.0                                      6.3
# 1                            34.0                                     19.8
# 2                            31.0                                      0.0
# 3                            31.0                                     13.6
# 4                            29.0                                      5.7
#
#    best_school_percentage_applying_to_victorian_uni best_school_school_name  \
# 0                                              83.0     albert park college
# 1                                              97.0  lauriston girls school
# 2                                              78.0                     NaN
# 3                                              91.0  university high school
# 4                                              54.0   holmes grammar school
#
#    avg_school_number_vce_subjects  ...  \
# 0                       57.000000  ...
# 1                       30.000000  ...
# 2                       42.583333  ...
# 3                       61.000000  ...
# 4                        9.000000  ...
#
#    zoned_school_study_score_over_40_percent  \
# 0                                  6.764547
# 1                                  7.744409
# 2                                  0.834947
# 3                                  8.240293
# 4                                 11.796245
#
#    zoned_school_percentage_applying_to_victorian_uni  \
# 0                                          78.993583
# 1                                          92.199390
# 2                                           7.270972
# 3                                          58.750247
# 4                                          85.339400
#
#                                             geometry  \
# 0  POLYGON ((144.97018001032677 -37.8606998481848...
# 1  POLYGON ((145.01167433388778 -37.8535692509816...
# 2  POLYGON ((144.95940340045405 -37.7847097769772...
# 3  POLYGON ((144.97476543627707 -37.7986360481138...
# 4  POLYGON ((144.95234670837857 -37.8151234866836...
#
#                                              regions  \
# 0                 ['Albert Park', 'St Kilda - West']
# 1                                       ['Armadale']
# 2                   ['Carlton North - Princes Hill']
# 3                           ['Carlton', 'Parkville']
# 4  ['Melbourne CBD - East', 'Melbourne CBD - Nort...
#
#                                 code  \
# 0             [206051128, 206051514]
# 1                        [206061135]
# 2                        [206071140]
# 3             [206041117, 206041124]
# 4  [206041504, 206041505, 206041503]
#
#                                          centroid  crow_distance_to_cbd  \
# 0   POINT (144.96815606060912 -37.85090369821219)              4.535857
# 1    POINT (145.02071077926166 -37.8567469622587)              7.261986
# 2   POINT (144.96813243979358 -37.78569850451154)              2.769950
# 3   POINT (144.95658060011763 -37.79124761163832)              2.178088
# 4  POINT (144.96257015435006 -37.813611663354884)              0.370739
#
#    distance_to_cbd  duration_to_cbd  \
# 0           6702.5            811.4
# 1          10138.0           1002.8
# 2           3171.0            396.3
# 3           3563.3            447.4
# 4           1420.9            231.6
#
#                                         route_to_cbd
# 0  [[144.967419, -37.851489], [144.967423, -37.85...
# 1  [[145.020491, -37.856724], [145.020572, -37.85...
# 2  [[144.968148, -37.785386], [144.968072, -37.78...
# 3  [[144.957623, -37.791118], [144.957388, -37.78...
# 4  [[144.962468, -37.81364], [144.962348, -37.813...
#
# [5 rows x 27 columns]

# %%
# Read 'crime.csv'
crime = pd.read_csv('../data/landing/crime.csv')
crime.head()
# Out:
#    Unnamed: 0                                suburbs  year year_ending  \
# 0           0  Albert Park-Middle Park-West St Kilda  2015        June
# 1           1  Albert Park-Middle Park-West St Kilda  2016        June
# 2           2  Albert Park-Middle Park-West St Kilda  2017        June
# 3           3  Albert Park-Middle Park-West St Kilda  2018        June
# 4           4  Albert Park-Middle Park-West St Kilda  2019        June
#
#    a20_assault_and_related_offences  a50_robbery  \
# 0                        178.045119    15.312481
# 1                        163.245015    18.871981
# 2                        168.857808    21.868907
# 3                        166.026923    20.091190
# 4                        183.604336    21.447080
#
#    a70_stalking,_harassment_and_threatening_behaviour  \
# 0                                          89.447606
# 1                                          60.409599
# 2                                          51.808850
# 3                                          43.838102
# 4                                          43.146675
#
#    a80_dangerous_and_negligent_acts_endangering_people  \
# 0                                          14.557886
# 1                                          12.829730
# 2                                          13.412846
# 3                                          13.860390
# 4                                          13.297669
#
#    other_crimes_against_the_person  b10_arson  ...  e10_justice_procedures  \
# 0                        71.608504   5.309056  ...               71.891770
# 1                        75.826735   8.872914  ...               70.024278
# 2                        77.006862   6.199418  ...               67.259923
# 3                        90.774467   3.861967  ...               62.168070
# 4                        80.959385   3.894443  ...               79.682981
#
#    e20_breaches_of_orders  f20_transport_regulation_offences  \
# 0              210.483706                           1.109359
# 1              282.063651                           5.377950
# 2              206.282406                           4.132875
# 3              209.469831                           0.351235
# 4              237.604554                           4.574256
#
#    f90_miscellaneous_offences  c90_other_drug_offences  \
# 0                    0.321457             9.142897e-01
# 1                    2.360719             1.157002e-09
# 2                    0.485045             1.616815e-01
# 3                    2.360719             1.616815e-01
# 4                    1.426281             8.347033e-03
#
#    f30_other_government_regulatory_offences  d40_public_security_offences  \
# 0                                 10.106054                      3.366460
# 1                                  5.624394                      1.606563
# 2                                  3.362648                      0.323363
# 3                                 14.268730                      4.813246
# 4                                  1.532163                      2.438106
#
#    f10_regulatory_driving_offences  b60_bribery  total_crimes
# 0                     1.075971e+00     0.323363   2586.271942
# 1                     4.664448e-01     0.161682   2712.910871
# 2                     0.000000e+00     0.008347   2789.178929
# 3                     1.178672e-08     0.485045   2532.279242
# 4                     1.571379e+00     0.304763   2518.652829
#
# [5 rows x 30 columns]

# %%
# Drop the columns 'Unnamed: 0' and 'year_ending'
crime = crime.drop(columns=['Unnamed: 0', 'year_ending'])

# Rename 'year' to 'years'
crime = crime.rename(columns={'year': 'years'})

# Detect missing values
crime.isnull().sum()
# Out:
# suburbs                                                0
# years                                                  0
# a20_assault_and_related_offences                       0
# a50_robbery                                            0
# a70_stalking,_harassment_and_threatening_behaviour     0
# a80_dangerous_and_negligent_acts_endangering_people    0
# other_crimes_against_the_person                        0
# b10_arson                                              0
# b20_property_damage                                    0
# b30_burglary/break_and_enter                           0
# b40_theft                                              0
# b50_deception                                          0
# c10_drug_dealing_and_trafficking                       0
# c20_cultivate_or_manufacture_drugs                     0
# c30_drug_use_and_possession                            0
# d10_weapons_and_explosives_offences                    0
# d20_disorderly_and_offensive_conduct                   0
# d30_public_nuisance_offences                           0
# e10_justice_procedures                                 0
# e20_breaches_of_orders                                 0
# f20_transport_regulation_offences                      0
# f90_miscellaneous_offences                             0
# c90_other_drug_offences                                0
# f30_other_government_regulatory_offences               0
# d40_public_security_offences                           0
# f10_regulatory_driving_offences                        0
# b60_bribery                                            0
# total_crimes                                           0
# dtype: int64

# %%
# Create the rows from 2002 to 2014 for each suburb
for i in range(2002, 2015):
    for suburb in crime['suburbs'].unique():
        crime = pd.concat([crime, pd.DataFrame({'suburbs': [suburb], 'years': [i]})], ignore_index=True)

# Impute data for combinations of year and suburb from 2002 to 2014 using extrapolation of the each suburb for each column respectively
for column in crime.columns[2:]:
    for suburb in crime['suburbs'].unique():
        crime.loc[crime['suburbs'] == suburb, column] = crime.loc[crime['suburbs'] == suburb, column].interpolate(method='linear', limit_direction='both')

# %%
# Join 'yearly_median' and 'crime' on combination of 'suburb' and 'year'
yearly_median = yearly_median.merge(crime, left_on=['suburb', 'year'], right_on=['suburbs', 'years'], how='left')
yearly_median = yearly_median.drop(columns=['suburbs', 'years'])
yearly_median.head()
# Out:
#                                   suburb  year  median_rent  \
# 0  Albert Park-Middle Park-West St Kilda  2002          300
# 1                               Armadale  2002          233
# 2                          Carlton North  2002          290
# 3                      Carlton-Parkville  2002          270
# 4                        CBD-St Kilda Rd  2002          320
#
#    best_school_number_vce_subjects  \
# 0                             57.0
# 1                             30.0
# 2                             43.0
# 3                             61.0
# 4                              9.0
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           99.0
# 1                                          100.0
# 2                                           99.0
# 3                                           97.0
# 4                                          100.0
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                            31.0                                      6.3
# 1                            34.0                                     19.8
# 2                            31.0                                      0.0
# 3                            31.0                                     13.6
# 4                            29.0                                      5.7
#
#    best_school_percentage_applying_to_victorian_uni best_school_school_name  \
# 0                                              83.0     albert park college
# 1                                              97.0  lauriston girls school
# 2                                              78.0                     NaN
# 3                                              91.0  university high school
# 4                                              54.0   holmes grammar school
#
#    avg_school_number_vce_subjects  ...  e10_justice_procedures  \
# 0                       57.000000  ...               60.500537
# 1                       30.000000  ...                9.378338
# 2                       42.583333  ...               12.000000
# 3                       61.000000  ...               23.916402
# 4                        9.000000  ...              297.999993
#
#    e20_breaches_of_orders  f20_transport_regulation_offences  \
# 0              288.770039                       1.282854e+00
# 1               13.968473                       1.156995e-08
# 2               19.000002                       2.347087e-08
# 3               81.418090                       8.683226e-01
# 4              445.999991                       1.500000e+01
#
#    f90_miscellaneous_offences  c90_other_drug_offences  \
# 0                1.936367e+00             1.616815e-01
# 1                7.277462e-09             0.000000e+00
# 2                3.387804e-08             7.569259e-09
# 3                1.797014e+00             5.942399e-02
# 4                1.000000e+01             5.000000e+00
#
#    f30_other_government_regulatory_offences  d40_public_security_offences  \
# 0                              3.500012e+00                  1.891674e+01
# 1                              9.684718e-01                  7.626006e-09
# 2                              3.729791e-08                  0.000000e+00
# 3                              2.336032e+00                  1.794770e-09
# 4                              2.100000e+01                  2.031652e-07
#
#    f10_regulatory_driving_offences  b60_bribery  total_crimes
# 0                     8.347033e-03          0.0   2586.379367
# 1                     1.819366e-09          0.0    605.270037
# 2                     0.000000e+00          0.0    780.000033
# 3                     2.376959e-02          0.0   1749.415541
# 4                     2.000000e+00          0.0  10326.999768
#
# [5 rows x 53 columns]

# %%
# Read 'land_cover.csv'
land_cover = pd.read_csv('../data/landing/land_cover.csv')
land_cover.head()
# Out:
#    Unnamed: 0                                suburbs  total_area  \
# 0           0  Albert Park-Middle Park-West St Kilda   7043125.0
# 1           1  Albert Park-Middle Park-West St Kilda   7043125.0
# 2           2  Albert Park-Middle Park-West St Kilda   7043125.0
# 3           3  Albert Park-Middle Park-West St Kilda   7043125.0
# 4           4  Albert Park-Middle Park-West St Kilda   7043125.0
#
#    developed_area  built_percentage  urban_percentage  disturbed_percentage  \
# 0       4691875.0          0.032212          0.595794              0.038158
# 1       4691875.0          0.032212          0.595794              0.038158
# 2       4691875.0          0.032212          0.595794              0.038158
# 3       4691875.0          0.032212          0.595794              0.038158
# 4       4691875.0          0.032212          0.595794              0.038158
#
#    water_percentage  developed_percentage  nature_percentage  year  quarter
# 0          0.047387              0.666164            0.28645  2000        1
# 1          0.047387              0.666164            0.28645  2000        2
# 2          0.047387              0.666164            0.28645  2000        3
# 3          0.047387              0.666164            0.28645  2000        4
# 4          0.047387              0.666164            0.28645  2001        1

# %%
# Drop the columns 'Unnamed: 0'
land_cover = land_cover.drop(columns=['Unnamed: 0'])

# Rename 'year' to 'years'
land_cover = land_cover.rename(columns={'year': 'years'})

# Detect missing values
land_cover.isnull().sum()
# Out:
# suburbs                 0
# total_area              0
# developed_area          0
# built_percentage        0
# urban_percentage        0
# disturbed_percentage    0
# water_percentage        0
# developed_percentage    0
# nature_percentage       0
# years                   0
# quarter                 0
# dtype: int64

# %%
# Keep the first quarter of each year
land_cover = land_cover[land_cover['quarter'] == 1]

# Drop the column 'quarter'
land_cover = land_cover.drop(columns=['quarter'])

# %%
# Create the rows from 2020 to 2023 for each suburb
for i in range(2020, 2024):
    for suburb in land_cover['suburbs'].unique():
        land_cover = pd.concat([land_cover, pd.DataFrame({'suburbs': [suburb], 'years': [i]})], ignore_index=True)

# Impute data for combinations of year and suburb from 2020 to 2023 using extrapolation of the each suburb for each column respectively
columns_to_interpolate = ['total_area', 'developed_area', 'built_percentage', 'urban_percentage', 'disturbed_percentage', 'water_percentage', 'developed_percentage', 'nature_percentage']
for column in columns_to_interpolate:
    for suburb in land_cover['suburbs'].unique():
        land_cover.loc[land_cover['suburbs'] == suburb, column] = land_cover.loc[land_cover['suburbs'] == suburb, column].interpolate(method='linear', limit_direction='both')

# %%
# Join 'yearly_median' and 'land_cover' on combination of 'suburb' and 'year'
yearly_median = yearly_median.merge(land_cover, left_on=['suburb', 'year'], right_on=['suburbs', 'years'], how='left')
yearly_median = yearly_median.drop(columns=['suburbs', 'years'])
yearly_median.head()
# Out:
#                                   suburb  year  median_rent  \
# 0  Albert Park-Middle Park-West St Kilda  2002          300
# 1                               Armadale  2002          233
# 2                          Carlton North  2002          290
# 3                      Carlton-Parkville  2002          270
# 4                        CBD-St Kilda Rd  2002          320
#
#    best_school_number_vce_subjects  \
# 0                             57.0
# 1                             30.0
# 2                             43.0
# 3                             61.0
# 4                              9.0
#
#    best_school_satisfactory_complete_vce_percent  \
# 0                                           99.0
# 1                                          100.0
# 2                                           99.0
# 3                                           97.0
# 4                                          100.0
#
#    best_school_median_study_score  best_school_study_score_over_40_percent  \
# 0                            31.0                                      6.3
# 1                            34.0                                     19.8
# 2                            31.0                                      0.0
# 3                            31.0                                     13.6
# 4                            29.0                                      5.7
#
#    best_school_percentage_applying_to_victorian_uni best_school_school_name  \
# 0                                              83.0     albert park college
# 1                                              97.0  lauriston girls school
# 2                                              78.0                     NaN
# 3                                              91.0  university high school
# 4                                              54.0   holmes grammar school
#
#    avg_school_number_vce_subjects  ...  b60_bribery  total_crimes  total_area  \
# 0                       57.000000  ...          0.0   2586.379367   7043125.0
# 1                       30.000000  ...          0.0    605.270037   2181875.0
# 2                       42.583333  ...          0.0    780.000033   2305625.0
# 3                       61.000000  ...          0.0   1749.415541   5855625.0
# 4                        9.000000  ...          0.0  10326.999768   2367500.0
#
#    developed_area  built_percentage  urban_percentage  disturbed_percentage  \
# 0       4691875.0          0.032212          0.595794              0.038158
# 1       2112500.0          0.026353          0.934403              0.007448
# 2       1977500.0          0.007861          0.843589              0.006235
# 3       4111875.0          0.066816          0.612766              0.022628
# 4       2187500.0          0.579461          0.287223              0.057286
#
#    water_percentage  developed_percentage nature_percentage
# 0          0.047387              0.666164          0.286450
# 1          0.000000              0.968204          0.031796
# 2          0.000000              0.857685          0.142315
# 3          0.000000              0.702209          0.297791
# 4          0.007656              0.923970          0.068374
#
# [5 rows x 61 columns]

# %%
# Save it to a csv file
yearly_median.to_csv('../data/curated/yearly_median_rent_by_suburb.csv', index=False)
