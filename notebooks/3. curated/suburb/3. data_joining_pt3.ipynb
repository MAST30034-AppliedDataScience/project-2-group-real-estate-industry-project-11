# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath('../../../scripts/2. modules'))
import processing

# Inputs
JOINED_PATH_LEFT = '../../../data/3. curated/merged/crime_schools_distances_land.csv'
JOINED_PATH_RIGHT = '../../../data/3. curated/merged/external_prices.csv'

# Outputs
OUTPUT_PATH = '../../../data/3. curated/merged'
OUTPUT_NAME = 'all_historical_data.csv'

# %%
df_left = pd.read_csv(JOINED_PATH_LEFT)
df_right = pd.read_csv(JOINED_PATH_RIGHT)

df_joined = pd.merge(df_left, df_right, on=['suburbs', 'year', 'quarter'])

# %% [markdown]
# Calculate per capita for the numeric features

# %%
merged_df_per_capita = df_joined.copy()

PER_CAPITA_COLUMNS = [ 'a20_assault_and_related_offences',
 'a50_robbery',
 'a70_stalking,_harassment_and_threatening_behaviour',
 'a80_dangerous_and_negligent_acts_endangering_people',
 'other_crimes_against_the_person',
 'b10_arson',
 'b20_property_damage',
 'b30_burglary/break_and_enter',
 'b40_theft',
 'b50_deception',
 'c10_drug_dealing_and_trafficking',
 'c20_cultivate_or_manufacture_drugs',
 'c30_drug_use_and_possession',
 'd10_weapons_and_explosives_offences',
 'd20_disorderly_and_offensive_conduct',
 'd30_public_nuisance_offences',
 'e10_justice_procedures',
 'e20_breaches_of_orders',
 'f20_transport_regulation_offences',
 'f90_miscellaneous_offences',
 'c90_other_drug_offences',
 'f30_other_government_regulatory_offences',
 'd40_public_security_offences',
 'f10_regulatory_driving_offences',
 'b60_bribery',
 'total_crimes',
 'economic: median age of earners',
 'economic: median income',
 'economic: top 5% suburb',
 'economic: top 1% suburb',
 'economic: gini coefficient',
 'economic: trimmed mean quarterly',
 'economic: variable interest rate',
 'economic: gdp quarterly',
 'economic: gdp per capita quarterly',
 'population: 0-4',
 'population: 5-9',
 'population: 10-14',
 'population: 15-19',
 'population: 20-24',
 'population: 25-29',
 'population: 30-34',
 'population: 35-39',
 'population: 40-44',
 'population: 45-49',
 'population: 50-54',
 'population: 55-59',
 'population: 60-64',
 'population: 65-69',
 'population: 70-74',
 'population: 75-79',
 'population: 80-84',
 'population: 85 and over',
 'birth: brazil',
 'birth: wales',
 'birth: papua new guinea',
 'birth: australia',
 'birth: malaysia',
 'birth: country of birth not stated',
 'birth: indonesia',
 'birth: egypt',
 'birth: afghanistan age',
 'birth: thailand',
 'birth: ireland',
 'birth: hong kong sar of china',
 'birth: nepal',
 'birth: north macedonia',
 'birth: england',
 'birth: chile',
 'birth: fiji',
 'birth: taiwan',
 'birth: japan',
 'birth: malta',
 'birth: scotland',
 'birth: china excludes sars and taiwan',
 'birth: poland',
 'birth: singapore',
 'birth: south africa',
 'birth: greece',
 'birth: pakistan',
 'birth: iraq',
 'birth: mauritius',
 'birth: samoa',
 'birth: sri lanka',
 'birth: india',
 'birth: philippines',
 'birth: vietnam',
 'birth: new zealand',
 'birth: iran',
 'birth: lebanon',
 'birth: france',
 'birth: total',
 'birth: netherlands',
 'birth: myanmar',
 'birth: united states of america',
 'birth: bosnia and herzegovina',
 'birth: zimbabwe',
 'birth: bangladesh',
 'birth: turkey',
 'birth: canada',
 'birth: korea republic of south',
 'birth: cambodia',
 'birth: born elsewhere',
 'birth: italy',
 'birth: croatia',
 'birth: germany',
 'studying: primary other',
 'studying: tertiary FT 14-25',
 'studying: tertiary FT 25+',
 'studying: primary total',
 'studying: tertiary PT 14-25',
 'studying: tertiary PT 25+',
 'studying: tafe total',
 'studying: primary government',
 'studying: secondary catholic',
 'studying: preschool',
 'studying: primary catholic',
 'studying: secondary government',
 'studying: secondary total',
 'studying: tertiary total',
 'overseas: 5 years',
 'relationships: child under 15',
 'relationships: defacto',
 'relationships: other related individual',
 'relationships: non dependent child',
 'relationships: lone persons',
 'relationships: group household',
 'relationships: married',
 'relationships: dependent student',
 'relationships: lone parents',
 'economic: number of earners',
 ]

for col in PER_CAPITA_COLUMNS:
    merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']

merged_df_per_capita = merged_df_per_capita.copy().drop(['Unnamed: 0.1', 'Unnamed: 0',], axis=1)
# Out:
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# /tmp/ipykernel_60123/1230335752.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_per_capita[col + '_pc'] = merged_df_per_capita[col] / merged_df_per_capita['population: total persons']
# ['suburbs',
#  'year',
#  'quarter',
#  'a20_assault_and_related_offences',
#  'a50_robbery',
#  'a70_stalking,_harassment_and_threatening_behaviour',
#  'a80_dangerous_and_negligent_acts_endangering_people',
#  'other_crimes_against_the_person',
#  'b10_arson',
#  'b20_property_damage',
#  'b30_burglary/break_and_enter',
#  'b40_theft',
#  'b50_deception',
#  'c10_drug_dealing_and_trafficking',
#  'c20_cultivate_or_manufacture_drugs',
#  'c30_drug_use_and_possession',
#  'd10_weapons_and_explosives_offences',
#  'd20_disorderly_and_offensive_conduct',
#  'd30_public_nuisance_offences',
#  'e10_justice_procedures',
#  'e20_breaches_of_orders',
#  'f20_transport_regulation_offences',
#  'f90_miscellaneous_offences',
#  'c90_other_drug_offences',
#  'f30_other_government_regulatory_offences',
#  'd40_public_security_offences',
#  'f10_regulatory_driving_offences',
#  'b60_bribery',
#  'total_crimes',
#  'best_school_number_vce_subjects',
#  'best_school_satisfactory_complete_vce_percent',
#  'best_school_median_study_score',
#  'best_school_study_score_over_40_percent',
#  'best_school_percentage_applying_to_victorian_uni',
#  'best_school_school_name',
#  'avg_school_number_vce_subjects',
#  'avg_school_satisfactory_complete_vce_percent',
#  'avg_school_median_study_score',
#  'avg_school_study_score_over_40_percent',
#  'avg_school_percentage_applying_to_victorian_uni',
#  'zoned_school_number_vce_subjects',
#  'zoned_school_satisfactory_complete_vce_percent',
#  'zoned_school_median_study_score',
#  'zoned_school_study_score_over_40_percent',
#  'zoned_school_percentage_applying_to_victorian_uni',
#  'crow_distance_to_cbd',
#  'distance_to_cbd',
#  'duration_to_cbd',
#  'total_area',
#  'developed_area',
#  'built_percentage',
#  'urban_percentage',
#  'disturbed_percentage',
#  'water_percentage',
#  'developed_percentage',
#  'nature_percentage',
#  'economic: median age of earners',
#  'economic: median income',
#  'economic: top 5% suburb',
#  'economic: top 1% suburb',
#  'economic: gini coefficient',
#  'economic: trimmed mean quarterly',
#  'economic: variable interest rate',
#  'economic: gdp quarterly',
#  'economic: gdp per capita quarterly',
#  'population: 0-4',
#  'population: 5-9',
#  'population: 10-14',
#  'population: 15-19',
#  'population: 20-24',
#  'population: 25-29',
#  'population: 30-34',
#  'population: 35-39',
#  'population: 40-44',
#  'population: 45-49',
#  'population: 50-54',
#  'population: 55-59',
#  'population: 60-64',
#  'population: 65-69',
#  'population: 70-74',
#  'population: 75-79',
#  'population: 80-84',
#  'population: 85 and over',
#  'population: total persons',
#  'population: growth',
#  'birth: brazil',
#  'birth: wales',
#  'birth: papua new guinea',
#  'birth: australia',
#  'birth: malaysia',
#  'birth: country of birth not stated',
#  'birth: indonesia',
#  'birth: egypt',
#  'birth: afghanistan age',
#  'birth: thailand',
#  'birth: ireland',
#  'birth: hong kong sar of china',
#  'birth: nepal',
#  'birth: north macedonia',
#  'birth: england',
#  'birth: chile',
#  'birth: fiji',
#  'birth: taiwan',
#  'birth: japan',
#  'birth: malta',
#  'birth: scotland',
#  'birth: china excludes sars and taiwan',
#  'birth: poland',
#  'birth: singapore',
#  'birth: south africa',
#  'birth: greece',
#  'birth: pakistan',
#  'birth: iraq',
#  'birth: mauritius',
#  'birth: samoa',
#  'birth: sri lanka',
#  'birth: india',
#  'birth: philippines',
#  'birth: vietnam',
#  'birth: new zealand',
#  'birth: iran',
#  'birth: lebanon',
#  'birth: france',
#  'birth: total',
#  'birth: netherlands',
#  'birth: myanmar',
#  'birth: united states of america',
#  'birth: bosnia and herzegovina',
#  'birth: zimbabwe',
#  'birth: bangladesh',
#  'birth: turkey',
#  'birth: canada',
#  'birth: korea republic of south',
#  'birth: cambodia',
#  'birth: born elsewhere',
#  'birth: italy',
#  'birth: croatia',
#  'birth: germany',
#  'studying: primary other',
#  'studying: tertiary FT 14-25',
#  'studying: tertiary FT 25+',
#  'studying: primary total',
#  'studying: tertiary PT 14-25',
#  'studying: tertiary PT 25+',
#  'studying: tafe total',
#  'studying: primary government',
#  'studying: secondary catholic',
#  'studying: preschool',
#  'studying: primary catholic',
#  'studying: secondary government',
#  'studying: secondary total',
#  'studying: tertiary total',
#  'overseas: 5 years',
#  'relationships: child under 15',
#  'relationships: defacto',
#  'relationships: other related individual',
#  'relationships: non dependent child',
#  'relationships: lone persons',
#  'relationships: group household',
#  'relationships: married',
#  'relationships: dependent student',
#  'relationships: lone parents',
#  'economic: number of earners',
#  'housing: type',
#  'housing: beds',
#  'housing: count',
#  'housing: median',
#  'housing: previous 2 years',
#  'housing: avg 2 years',
#  'a20_assault_and_related_offences_pc',
#  'a50_robbery_pc',
#  'a70_stalking,_harassment_and_threatening_behaviour_pc',
#  'a80_dangerous_and_negligent_acts_endangering_people_pc',
#  'other_crimes_against_the_person_pc',
#  'b10_arson_pc',
#  'b20_property_damage_pc',
#  'b30_burglary/break_and_enter_pc',
#  'b40_theft_pc',
#  'b50_deception_pc',
#  'c10_drug_dealing_and_trafficking_pc',
#  'c20_cultivate_or_manufacture_drugs_pc',
#  'c30_drug_use_and_possession_pc',
#  'd10_weapons_and_explosives_offences_pc',
#  'd20_disorderly_and_offensive_conduct_pc',
#  'd30_public_nuisance_offences_pc',
#  'e10_justice_procedures_pc',
#  'e20_breaches_of_orders_pc',
#  'f20_transport_regulation_offences_pc',
#  'f90_miscellaneous_offences_pc',
#  'c90_other_drug_offences_pc',
#  'f30_other_government_regulatory_offences_pc',
#  'd40_public_security_offences_pc',
#  'f10_regulatory_driving_offences_pc',
#  'b60_bribery_pc',
#  'total_crimes_pc',
#  'economic: median age of earners_pc',
#  'economic: median income_pc',
#  'economic: top 5% suburb_pc',
#  'economic: top 1% suburb_pc',
#  'economic: gini coefficient_pc',
#  'economic: trimmed mean quarterly_pc',
#  'economic: variable interest rate_pc',
#  'economic: gdp quarterly_pc',
#  'economic: gdp per capita quarterly_pc',
#  'population: 0-4_pc',
#  'population: 5-9_pc',
#  'population: 10-14_pc',
#  'population: 15-19_pc',
#  'population: 20-24_pc',
#  'population: 25-29_pc',
#  'population: 30-34_pc',
#  'population: 35-39_pc',
#  'population: 40-44_pc',
#  'population: 45-49_pc',
#  'population: 50-54_pc',
#  'population: 55-59_pc',
#  'population: 60-64_pc',
#  'population: 65-69_pc',
#  'population: 70-74_pc',
#  'population: 75-79_pc',
#  'population: 80-84_pc',
#  'population: 85 and over_pc',
#  'birth: brazil_pc',
#  'birth: wales_pc',
#  'birth: papua new guinea_pc',
#  'birth: australia_pc',
#  'birth: malaysia_pc',
#  'birth: country of birth not stated_pc',
#  'birth: indonesia_pc',
#  'birth: egypt_pc',
#  'birth: afghanistan age_pc',
#  'birth: thailand_pc',
#  'birth: ireland_pc',
#  'birth: hong kong sar of china_pc',
#  'birth: nepal_pc',
#  'birth: north macedonia_pc',
#  'birth: england_pc',
#  'birth: chile_pc',
#  'birth: fiji_pc',
#  'birth: taiwan_pc',
#  'birth: japan_pc',
#  'birth: malta_pc',
#  'birth: scotland_pc',
#  'birth: china excludes sars and taiwan_pc',
#  'birth: poland_pc',
#  'birth: singapore_pc',
#  'birth: south africa_pc',
#  'birth: greece_pc',
#  'birth: pakistan_pc',
#  'birth: iraq_pc',
#  'birth: mauritius_pc',
#  'birth: samoa_pc',
#  'birth: sri lanka_pc',
#  'birth: india_pc',
#  'birth: philippines_pc',
#  'birth: vietnam_pc',
#  'birth: new zealand_pc',
#  'birth: iran_pc',
#  'birth: lebanon_pc',
#  'birth: france_pc',
#  'birth: total_pc',
#  'birth: netherlands_pc',
#  'birth: myanmar_pc',
#  'birth: united states of america_pc',
#  'birth: bosnia and herzegovina_pc',
#  'birth: zimbabwe_pc',
#  'birth: bangladesh_pc',
#  'birth: turkey_pc',
#  'birth: canada_pc',
#  'birth: korea republic of south_pc',
#  'birth: cambodia_pc',
#  'birth: born elsewhere_pc',
#  'birth: italy_pc',
#  'birth: croatia_pc',
#  'birth: germany_pc',
#  'studying: primary other_pc',
#  'studying: tertiary FT 14-25_pc',
#  'studying: tertiary FT 25+_pc',
#  'studying: primary total_pc',
#  'studying: tertiary PT 14-25_pc',
#  'studying: tertiary PT 25+_pc',
#  'studying: tafe total_pc',
#  'studying: primary government_pc',
#  'studying: secondary catholic_pc',
#  'studying: preschool_pc',
#  'studying: primary catholic_pc',
#  'studying: secondary government_pc',
#  'studying: secondary total_pc',
#  'studying: tertiary total_pc',
#  'overseas: 5 years_pc',
#  'relationships: child under 15_pc',
#  'relationships: defacto_pc',
#  'relationships: other related individual_pc',
#  'relationships: non dependent child_pc',
#  'relationships: lone persons_pc',
#  'relationships: group household_pc',
#  'relationships: married_pc',
#  'relationships: dependent student_pc',
#  'relationships: lone parents_pc',
#  'economic: number of earners_pc']

# %%
processing.to_csv(merged_df_per_capita, OUTPUT_PATH, OUTPUT_NAME)
